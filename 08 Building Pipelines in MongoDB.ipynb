# %% [markdown]
# ### Problem Statement
#
#
# The data is related to stocks listed on a stock market. There are 103 unique stocks in the provided dataset which contains stocks that are listed on a public stock exchange, as well as those that are traded privately, such as shares of private companies which are sold to investors through equity crowdfunding platforms.
#
# The documents in the dataset have the following fields -
#
# - stock - Unique ID for a stock
#
# - date - Date for which the stock prices are provided
#
# - open - Opening price of the stock on a trading day
#
# - high - Highest price of the stock on a trading day
#
# - low - Lowest price of the stock on a trading day
#
# - close - Closing price of the stock on a trading day
#
# - holiday - Whether there is a holiday or not (0/1)
#
# ----

# %% [markdown]
# ### Connecting to MongoDB
#
#
# ----

# %%
# Importing the required libraries
import pymongo
import pprint as pp
from datetime import datetime

pp.sorted = lambda x, key=None: x

# %%
client = pymongo.MongoClient("mongodb://localhost:27017/")

# %%
# Check
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %% [markdown]
# ---
# ### Importing data
#
# ----

# %%
# # Restore database
# mongorestore --nsInclude av.stock c:\temp\av\stock.bson

# %%
# List databases
client.list_database_names()
# Out:
# ['admin', 'av', 'config', 'local', 'sample', 'sample_analytics']

# %%
# Choose database
db = client.av

# %%
# List collection names
db.list_collection_names()
# Out:
# ['demo_csv', 'challenge', 'clicks', 'stock']

# %%
# sample document
pp.pprint(db.stock.find_one())
# Out:
# {'_id': ObjectId('60d9930f5922a69299cb36c7'),
#  'stock': 0,
#  'date': datetime.datetime(2017, 1, 3, 0, 0),
#  'open': 82.9961,
#  'high': 82.7396,
#  'low': 82.9144,
#  'close': 82.8101,
#  'holiday': 1}

# %%
# Number of documents
db.stock.count_documents({})
# Out:
# 73439

# %% [markdown]
# ----
# ### Assignment Questions
#
# ----

# %% [markdown]
# ###  Q1
#
# Average `open`, `close`, `high` and `low` price of each stock

# %%
# Enter your code here
cur = db.stock.aggregate(
        [ 
            { 
                '$group' :{
                    '_id' : '$stock' ,
                    'avg_open':{'$avg' : '$open'},
                    'avg_high':{'$avg' : '$high'},
                    'avg_low':{'$avg' : '$low'},
                    'avg_close':{'$avg' : '$close'} }
            },
            { '$sort' : {'_id':1}}
        ]
)
# Print docs
for doc in cur :
    pp.pprint(doc)
# Out:
# {'_id': 0,
#  'avg_open': 95.88621683029453,
#  'avg_high': 96.05897180925666,
#  'avg_low': 95.82947363253857,
#  'avg_close': 95.94544908835906}
# {'_id': 1,
#  'avg_open': 41.558860448807856,
#  'avg_high': 41.405781206171106,
#  'avg_low': 41.80903534361851,
#  'avg_close': 41.60243239831697}
# {'_id': 2,
#  'avg_open': 140.3445535764376,
#  'avg_high': 139.84877461430577,
#  'avg_low': 141.07150645161292,
#  'avg_close': 140.42709172510519}
# {'_id': 3,
#  'avg_open': 68.94725287517532,
#  'avg_high': 68.85066016830295,
#  'avg_low': 69.23658316970547,
#  'avg_close': 69.06451711079943}
# {'_id': 4,
#  'avg_open': 77.82345946704068,
#  'avg_high': 78.14658681626929,
#  'avg_low': 77.54579396914447,
#  'avg_close': 77.80921921458625}
# {'_id': 5,
#  'avg_open': 120.20878036465639,
#  'avg_high': 120.9454366058906,
#  'avg_low': 119.47728036465638,
#  'avg_close': 120.26952496493689}
# {'_id': 6,
#  'avg_open': 112.04822356241235,
#  'avg_high': 111.74747741935485,
#  'avg_low': 112.67421332398317,
#  'avg_close': 112.21803001402526}
# {'_id': 7,
#  'avg_open': 143.2071760168303,
#  'avg_high': 142.8986237026648,
#  'avg_low': 143.8395772791024,
#  'avg_close': 143.35986942496493}
# {'_id': 8,
#  'avg_open': 59.02509453015427,
#  'avg_high': 58.960799438990186,
#  'avg_low': 59.23593506311361,
#  'avg_close': 59.10351739130435}
# {'_id': 9,
#  'avg_open': 169.6208824684432,
#  'avg_high': 169.41739971949508,
#  'avg_low': 169.9114239831697,
#  'avg_close': 169.61429593267883}
# {'_id': 10,
#  'avg_open': 51.51756171107995,
#  'avg_high': 51.39847363253857,
#  'avg_low': 51.70049761570827,
#  'avg_close': 51.558731136044884}
# {'_id': 11,
#  'avg_open': 82.09242524544179,
#  'avg_high': 81.9233904628331,
#  'avg_low': 82.52200448807854,
#  'avg_close': 82.21850420757363}
# {'_id': 12,
#  'avg_open': 53.171464375876575,
#  'avg_high': 53.48613239831697,
#  'avg_low': 52.90849747545582,
#  'avg_close': 53.21541893408134}
# {'_id': 13,
#  'avg_open': 51.98053899018233,
#  'avg_high': 51.97625147265077,
#  'avg_low': 52.108178681626924,
#  'avg_close': 52.06004109396915}
# {'_id': 14,
#  'avg_open': 71.11668345021037,
#  'avg_high': 70.8312098176718,
#  'avg_low': 71.54770701262272,
#  'avg_close': 71.17839817671809}
# {'_id': 15,
#  'avg_open': 60.57695553997195,
#  'avg_high': 60.3084713884993,
#  'avg_low': 60.977003085553996,
#  'avg_close': 60.634749228611504}
# {'_id': 16,
#  'avg_open': 54.384418513323986,
#  'avg_high': 54.31821051893409,
#  'avg_low': 54.517269284712484,
#  'avg_close': 54.43061458625526}
# {'_id': 17,
#  'avg_open': 57.25564025245442,
#  'avg_high': 57.014755680224404,
#  'avg_low': 57.64265315568022,
#  'avg_close': 57.32155511921459}
# {'_id': 18,
#  'avg_open': 66.23328597475457,
#  'avg_high': 66.15575273492287,
#  'avg_low': 66.48256409537167,
#  'avg_close': 66.33005736325386}
# {'_id': 19,
#  'avg_open': 112.79028302945301,
#  'avg_high': 112.70801556802245,
#  'avg_low': 113.24651711079945,
#  'avg_close': 112.97796311360449}
# {'_id': 20,
#  'avg_open': 64.01812720897617,
#  'avg_high': 63.92388765778401,
#  'avg_low': 64.20530112201963,
#  'avg_close': 64.07374502103787}
# {'_id': 21,
#  'avg_open': 70.6950159887798,
#  'avg_high': 70.66057237026648,
#  'avg_low': 70.94167208976157,
#  'avg_close': 70.82683464235625}
# {'_id': 22,
#  'avg_open': 51.89104137447406,
#  'avg_high': 51.76603239831697,
#  'avg_low': 52.12439116409537,
#  'avg_close': 51.93571360448808}
# {'_id': 23,
#  'avg_open': 53.28864319775597,
#  'avg_high': 53.10334656381487,
#  'avg_low': 53.57439943899018,
#  'avg_close': 53.33365960729312}
# {'_id': 24,
#  'avg_open': 94.66463099579242,
#  'avg_high': 94.30373281907433,
#  'avg_low': 95.34401051893408,
#  'avg_close': 94.84485862552594}
# {'_id': 25,
#  'avg_open': 44.677060729312764,
#  'avg_high': 44.61173786816269,
#  'avg_low': 44.77580084151473,
#  'avg_close': 44.70324207573633}
# {'_id': 26,
#  'avg_open': 83.35057531556802,
#  'avg_high': 83.70140462833099,
#  'avg_low': 83.41838218793829,
#  'avg_close': 83.64982047685835}
# {'_id': 27,
#  'avg_open': 47.88822019635344,
#  'avg_high': 47.96871725105189,
#  'avg_low': 47.873380224403924,
#  'avg_close': 47.90184137447405}
# {'_id': 28,
#  'avg_open': 26.501187657784012,
#  'avg_high': 26.499538288920057,
#  'avg_low': 26.56423899018233,
#  'avg_close': 26.534147124824685}
# {'_id': 29,
#  'avg_open': 43.29716577840112,
#  'avg_high': 43.14164109396914,
#  'avg_low': 43.525693828892,
#  'avg_close': 43.33165904628331}
# {'_id': 30,
#  'avg_open': 67.3447523141655,
#  'avg_high': 67.17590855539972,
#  'avg_low': 67.66119396914445,
#  'avg_close': 67.41070322580646}
# {'_id': 31,
#  'avg_open': 81.58857433380084,
#  'avg_high': 81.72123197755961,
#  'avg_low': 81.61744810659187,
#  'avg_close': 81.66544460028051}
# {'_id': 32,
#  'avg_open': 49.19720098176718,
#  'avg_high': 49.090517391304346,
#  'avg_low': 49.36762384291725,
#  'avg_close': 49.21706872370266}
# {'_id': 33,
#  'avg_open': 56.33758232819074,
#  'avg_high': 56.28129677419354,
#  'avg_low': 56.58076255259468,
#  'avg_close': 56.43058513323983}
# {'_id': 34,
#  'avg_open': 76.93426802244039,
#  'avg_high': 76.69864053295933,
#  'avg_low': 77.38469116409537,
#  'avg_close': 77.04030631136045}
# {'_id': 35,
#  'avg_open': 53.57459915848528,
#  'avg_high': 53.50146647966339,
#  'avg_low': 53.73858948106592,
#  'avg_close': 53.6337190743338}
# {'_id': 36,
#  'avg_open': 72.19134109396914,
#  'avg_high': 72.65603492286115,
#  'avg_low': 71.90179396914445,
#  'avg_close': 72.2665424964937}
# {'_id': 37,
#  'avg_open': 73.13897924263675,
#  'avg_high': 72.90937223001403,
#  'avg_low': 73.70079747545581,
#  'avg_close': 73.3182698457223}
# {'_id': 38,
#  'avg_open': 29.853210518934084,
#  'avg_high': 29.787527769985978,
#  'avg_low': 29.985036325385696,
#  'avg_close': 29.88912314165498}
# {'_id': 39,
#  'avg_open': 30.714492566619914,
#  'avg_high': 30.733953856942495,
#  'avg_low': 30.773104908835904,
#  'avg_close': 30.747237587657782}
# {'_id': 40,
#  'avg_open': 43.20541430575035,
#  'avg_high': 43.078863674614304,
#  'avg_low': 43.4052335203366,
#  'avg_close': 43.24136690042076}
# {'_id': 41,
#  'avg_open': 107.86122230014026,
#  'avg_high': 108.21904151472651,
#  'avg_low': 107.93051458625527,
#  'avg_close': 108.10607223001402}
# {'_id': 42,
#  'avg_open': 53.55136171107995,
#  'avg_high': 53.7764237026648,
#  'avg_low': 53.44716704067321,
#  'avg_close': 53.60887419354839}
# {'_id': 43,
#  'avg_open': 47.65778134642356,
#  'avg_high': 47.501512061711075,
#  'avg_low': 47.91005624123422,
#  'avg_close': 47.693918934081346}
# {'_id': 44,
#  'avg_open': 78.10636100981768,
#  'avg_high': 77.95497699859747,
#  'avg_low': 78.51227910238428,
#  'avg_close': 78.2499744740533}
# {'_id': 45,
#  'avg_open': 67.33562805049088,
#  'avg_high': 67.94959060308555,
#  'avg_low': 67.17678877980364,
#  'avg_close': 67.60848849929873}
# {'_id': 46,
#  'avg_open': 110.74063267882188,
#  'avg_high': 110.93900182328191,
#  'avg_low': 110.87078176718093,
#  'avg_close': 110.91927517531556}
# {'_id': 47,
#  'avg_open': 132.35824193548387,
#  'avg_high': 132.22024193548387,
#  'avg_low': 132.97774600280505,
#  'avg_close': 132.62408541374472}
# {'_id': 48,
#  'avg_open': 84.22664179523142,
#  'avg_high': 84.05373856942497,
#  'avg_low': 84.63178779803646,
#  'avg_close': 84.33649523141655}
# {'_id': 49,
#  'avg_open': 45.3601904628331,
#  'avg_high': 45.28695259467041,
#  'avg_low': 45.50074011220196,
#  'avg_close': 45.404029453015426}
# {'_id': 50,
#  'avg_open': 154.70814165497896,
#  'avg_high': 155.33922608695653,
#  'avg_low': 154.3270237026648,
#  'avg_close': 154.8385043478261}
# {'_id': 51,
#  'avg_open': 85.55061711079944,
#  'avg_high': 85.18784179523142,
#  'avg_low': 86.24584670406732,
#  'avg_close': 85.72807335203366}
# {'_id': 52,
#  'avg_open': 63.05543169705469,
#  'avg_high': 63.41916563814867,
#  'avg_low': 62.765890743338005,
#  'avg_close': 63.10707391304347}
# {'_id': 53,
#  'avg_open': 30.101458625525947,
#  'avg_high': 30.087697054698456,
#  'avg_low': 30.182420757363253,
#  'avg_close': 30.137011360448806}
# {'_id': 54,
#  'avg_open': 71.42049214586255,
#  'avg_high': 71.60273267882188,
#  'avg_low': 71.32481023842917,
#  'avg_close': 71.45258990182329}
# {'_id': 55,
#  'avg_open': 71.70732594670407,
#  'avg_high': 71.60506143057503,
#  'avg_low': 71.9236556802244,
#  'avg_close': 71.72747952314165}
# {'_id': 56,
#  'avg_open': 45.24806325385694,
#  'avg_high': 45.21020056100982,
#  'avg_low': 45.388918513323986,
#  'avg_close': 45.310740813464236}
# {'_id': 57,
#  'avg_open': 95.01563870967742,
#  'avg_high': 94.96093983169705,
#  'avg_low': 95.28481683029453,
#  'avg_close': 95.11734291725105}
# {'_id': 58,
#  'avg_open': 54.89824530154278,
#  'avg_high': 55.01860673211782,
#  'avg_low': 54.744698597475455,
#  'avg_close': 54.89860701262272}
# {'_id': 59,
#  'avg_open': 48.77201150070126,
#  'avg_high': 48.60005708274895,
#  'avg_low': 49.03650392706873,
#  'avg_close': 48.811326928471246}
# {'_id': 60,
#  'avg_open': 82.92270350631136,
#  'avg_high': 82.85887096774194,
#  'avg_low': 83.04639424964937,
#  'avg_close': 82.96457377279103}
# {'_id': 61,
#  'avg_open': 27.212900841514724,
#  'avg_high': 27.342400280504908,
#  'avg_low': 27.174307713884993,
#  'avg_close': 27.26069074333801}
# {'_id': 62,
#  'avg_open': 93.79414936886396,
#  'avg_high': 93.64037363253857,
#  'avg_low': 94.11302847124826,
#  'avg_close': 93.88445553997195}
# {'_id': 63,
#  'avg_open': 33.59390855539972,
#  'avg_high': 33.596929733520334,
#  'avg_low': 33.68099971949509,
#  'avg_close': 33.640787938288916}
# {'_id': 64,
#  'avg_open': 113.99501206171108,
#  'avg_high': 113.76654474053296,
#  'avg_low': 114.48530462833101,
#  'avg_close': 114.1237950911641}
# {'_id': 65,
#  'avg_open': 51.50624319775596,
#  'avg_high': 51.801572230014024,
#  'avg_low': 51.33319551192145,
#  'avg_close': 51.58375441795231}
# {'_id': 66,
#  'avg_open': 130.72092580645162,
#  'avg_high': 130.94789761570826,
#  'avg_low': 130.65055469845723,
#  'avg_close': 130.80564586255258}
# {'_id': 67,
#  'avg_open': 62.43564964936886,
#  'avg_high': 62.16426914446003,
#  'avg_low': 62.84850056100982,
#  'avg_close': 62.504803506311355}
# {'_id': 68,
#  'avg_open': 38.63039901823282,
#  'avg_high': 38.74078050490884,
#  'avg_low': 38.585981206171105,
#  'avg_close': 38.66401065918654}
# {'_id': 69,
#  'avg_open': 92.17475077138849,
#  'avg_high': 92.11692412342215,
#  'avg_low': 92.48287054698457,
#  'avg_close': 92.30903071528752}
# {'_id': 70,
#  'avg_open': 116.5602793828892,
#  'avg_high': 116.05634193548387,
#  'avg_low': 117.4224443197756,
#  'avg_close': 116.74039340813465}
# {'_id': 71,
#  'avg_open': 58.04542103786816,
#  'avg_high': 57.86039495091165,
#  'avg_low': 58.30581220196353,
#  'avg_close': 58.06093127629734}
# {'_id': 72,
#  'avg_open': 42.378611640953714,
#  'avg_high': 42.33630462833099,
#  'avg_low': 42.50184586255259,
#  'avg_close': 42.41895427769986}
# {'_id': 73,
#  'avg_open': 95.23458316970547,
#  'avg_high': 95.07190785413745,
#  'avg_low': 95.70415988779804,
#  'avg_close': 95.38145652173912}
# {'_id': 74,
#  'avg_open': 75.13953688639552,
#  'avg_high': 75.27805119214587,
#  'avg_low': 75.13682931276297,
#  'avg_close': 75.21768807854137}
# {'_id': 75,
#  'avg_open': 90.2059556802244,
#  'avg_high': 90.16253464235623,
#  'avg_low': 90.29889789621318,
#  'avg_close': 90.2365144460028}
# {'_id': 76,
#  'avg_open': 39.550783029453015,
#  'avg_high': 39.42657573632538,
#  'avg_low': 39.78240813464236,
#  'avg_close': 39.604289340813466}
# {'_id': 77,
#  'avg_open': 71.90842033660589,
#  'avg_high': 72.0434332398317,
#  'avg_low': 71.83065960729313,
#  'avg_close': 71.91910883590462}
# {'_id': 78,
#  'avg_open': 86.26474670406732,
#  'avg_high': 85.97144656381487,
#  'avg_low': 86.63334516129032,
#  'avg_close': 86.26611009817671}
# {'_id': 79,
#  'avg_open': 82.96184558204769,
#  'avg_high': 83.07664698457222,
#  'avg_low': 83.14104684431977,
#  'avg_close': 83.13150042075736}
# {'_id': 80,
#  'avg_open': 84.44384586255259,
#  'avg_high': 84.82993408134642,
#  'avg_low': 84.2055618513324,
#  'avg_close': 84.51997882187938}
# {'_id': 81,
#  'avg_open': 57.24292482468443,
#  'avg_high': 57.037301683029455,
#  'avg_low': 57.74327180925666,
#  'avg_close': 57.40925189340814}
# {'_id': 82,
#  'avg_open': 110.95845652173912,
#  'avg_high': 110.67413155680224,
#  'avg_low': 111.54876788218795,
#  'avg_close': 111.11936872370266}
# {'_id': 83,
#  'avg_open': 139.1049187938289,
#  'avg_high': 138.78610420757363,
#  'avg_low': 139.81112650771388,
#  'avg_close': 139.30948457223002}
# {'_id': 84,
#  'avg_open': 48.19802748948106,
#  'avg_high': 48.13411809256662,
#  'avg_low': 48.37683366058906,
#  'avg_close': 48.25954417952314}
# {'_id': 85,
#  'avg_open': 82.53110434782609,
#  'avg_high': 82.48341051893408,
#  'avg_low': 82.62555904628331,
#  'avg_close': 82.56149495091164}
# {'_id': 86,
#  'avg_open': 74.68796998597475,
#  'avg_high': 74.59601037868163,
#  'avg_low': 74.8149255259467,
#  'avg_close': 74.69280631136044}
# {'_id': 87,
#  'avg_open': 113.62765890603086,
#  'avg_high': 113.69252272089761,
#  'avg_low': 113.97296199158485,
#  'avg_close': 113.86575189340813}
# {'_id': 88,
#  'avg_open': 74.5064095371669,
#  'avg_high': 74.64095624123422,
#  'avg_low': 74.56128990182327,
#  'avg_close': 74.60835007012622}
# {'_id': 89,
#  'avg_open': 36.545057363253854,
#  'avg_high': 36.50310743338008,
#  'avg_low': 36.601414866760166,
#  'avg_close': 36.530376998597475}
# {'_id': 90,
#  'avg_open': 56.65938499298738,
#  'avg_high': 56.579422019635345,
#  'avg_low': 56.82778541374474,
#  'avg_close': 56.7106175315568}
# {'_id': 91,
#  'avg_open': 56.39402538569425,
#  'avg_high': 56.760186956521736,
#  'avg_low': 56.10947952314166,
#  'avg_close': 56.435293127629734}
# {'_id': 92,
#  'avg_open': 101.63392510518933,
#  'avg_high': 102.12194698457223,
#  'avg_low': 101.27653492286115,
#  'avg_close': 101.66332762973353}
# {'_id': 93,
#  'avg_open': 44.372932819074336,
#  'avg_high': 44.52891332398317,
#  'avg_low': 44.27474375876578,
#  'avg_close': 44.38982103786816}
# {'_id': 94,
#  'avg_open': 90.60398639551192,
#  'avg_high': 90.60424516129032,
#  'avg_low': 91.13148625525946,
#  'avg_close': 90.92161430575035}
# {'_id': 95,
#  'avg_open': 45.13282440392707,
#  'avg_high': 45.3281920056101,
#  'avg_low': 45.0529840112202,
#  'avg_close': 45.195693267882184}
# {'_id': 96,
#  'avg_open': 129.09340266479663,
#  'avg_high': 129.82869410939693,
#  'avg_low': 128.5026971949509,
#  'avg_close': 129.18487812061713}
# {'_id': 97,
#  'avg_open': 108.86678443197756,
#  'avg_high': 109.41950378681626,
#  'avg_low': 108.48191388499299,
#  'avg_close': 108.91458892005609}
# {'_id': 98,
#  'avg_open': 120.66434081346424,
#  'avg_high': 121.28436844319776,
#  'avg_low': 120.19527208976157,
#  'avg_close': 120.7587474053296}
# {'_id': 99,
#  'avg_open': 46.798312342215986,
#  'avg_high': 47.36147194950912,
#  'avg_low': 46.29965792426368,
#  'avg_close': 46.836982889200556}
# {'_id': 100,
#  'avg_open': 57.371028471248245,
#  'avg_high': 57.276799579242635,
#  'avg_low': 57.58370771388499,
#  'avg_close': 57.43880406732117}
# {'_id': 101,
#  'avg_open': 118.31463492286116,
#  'avg_high': 118.9201842917251,
#  'avg_low': 117.75677882187938,
#  'avg_close': 118.37751206171109}
# {'_id': 102,
#  'avg_open': 132.36579957924263,
#  'avg_high': 132.25708443197757,
#  'avg_low': 132.63169677419356,
#  'avg_close': 132.46648835904628}

# %% [markdown]
# ### Q2
#
# Top 10 stocks that have the highest maximum `high` price.

# %%
cur = db.stock.aggregate(
        [ 
            { 
                '$group' :{
                    '_id' : '$stock' ,
                    'max_high':{'$max' : '$high'} }
            },
            { '$sort' : {
                'max_high':-1}
            },
            { '$limit' : 10
            }
        ]
)
# Print docs
for doc in cur :
    pp.pprint(doc)
# Out:
# {'_id': 50, 'max_high': 233.6489}
# {'_id': 9, 'max_high': 188.8665}
# {'_id': 96, 'max_high': 172.6228}
# {'_id': 41, 'max_high': 169.8708}
# {'_id': 5, 'max_high': 163.3879}
# {'_id': 98, 'max_high': 162.5328}
# {'_id': 83, 'max_high': 157.7866}
# {'_id': 7, 'max_high': 155.5095}
# {'_id': 101, 'max_high': 152.0819}
# {'_id': 66, 'max_high': 151.0963}

# %% [markdown]
# ### Q3
#
# Find the number of days for each stock for which it had `close` price more than the `open` price.

# %%
# First check data for how many days for each stock
count = db.stock.aggregate(
    [
        {
            '$group' : {
                '_id' : '$stock',
                'Count': {'$sum': 1}
            }
        },
        {
            '$sort': {'_id':1}
        },
#         { 
#             '$limit' : 20
#         }
    ]
)
# Print output
for doc in count :
    pp.pprint(doc)
# Out:
# {'_id': 0, 'Count': 713}
# {'_id': 1, 'Count': 713}
# {'_id': 2, 'Count': 713}
# {'_id': 3, 'Count': 713}
# {'_id': 4, 'Count': 713}
# {'_id': 5, 'Count': 713}
# {'_id': 6, 'Count': 713}
# {'_id': 7, 'Count': 713}
# {'_id': 8, 'Count': 713}
# {'_id': 9, 'Count': 713}
# {'_id': 10, 'Count': 713}
# {'_id': 11, 'Count': 713}
# {'_id': 12, 'Count': 713}
# {'_id': 13, 'Count': 713}
# {'_id': 14, 'Count': 713}
# {'_id': 15, 'Count': 713}
# {'_id': 16, 'Count': 713}
# {'_id': 17, 'Count': 713}
# {'_id': 18, 'Count': 713}
# {'_id': 19, 'Count': 713}
# {'_id': 20, 'Count': 713}
# {'_id': 21, 'Count': 713}
# {'_id': 22, 'Count': 713}
# {'_id': 23, 'Count': 713}
# {'_id': 24, 'Count': 713}
# {'_id': 25, 'Count': 713}
# {'_id': 26, 'Count': 713}
# {'_id': 27, 'Count': 713}
# {'_id': 28, 'Count': 713}
# {'_id': 29, 'Count': 713}
# {'_id': 30, 'Count': 713}
# {'_id': 31, 'Count': 713}
# {'_id': 32, 'Count': 713}
# {'_id': 33, 'Count': 713}
# {'_id': 34, 'Count': 713}
# {'_id': 35, 'Count': 713}
# {'_id': 36, 'Count': 713}
# {'_id': 37, 'Count': 713}
# {'_id': 38, 'Count': 713}
# {'_id': 39, 'Count': 713}
# {'_id': 40, 'Count': 713}
# {'_id': 41, 'Count': 713}
# {'_id': 42, 'Count': 713}
# {'_id': 43, 'Count': 713}
# {'_id': 44, 'Count': 713}
# {'_id': 45, 'Count': 713}
# {'_id': 46, 'Count': 713}
# {'_id': 47, 'Count': 713}
# {'_id': 48, 'Count': 713}
# {'_id': 49, 'Count': 713}
# {'_id': 50, 'Count': 713}
# {'_id': 51, 'Count': 713}
# {'_id': 52, 'Count': 713}
# {'_id': 53, 'Count': 713}
# {'_id': 54, 'Count': 713}
# {'_id': 55, 'Count': 713}
# {'_id': 56, 'Count': 713}
# {'_id': 57, 'Count': 713}
# {'_id': 58, 'Count': 713}
# {'_id': 59, 'Count': 713}
# {'_id': 60, 'Count': 713}
# {'_id': 61, 'Count': 713}
# {'_id': 62, 'Count': 713}
# {'_id': 63, 'Count': 713}
# {'_id': 64, 'Count': 713}
# {'_id': 65, 'Count': 713}
# {'_id': 66, 'Count': 713}
# {'_id': 67, 'Count': 713}
# {'_id': 68, 'Count': 713}
# {'_id': 69, 'Count': 713}
# {'_id': 70, 'Count': 713}
# {'_id': 71, 'Count': 713}
# {'_id': 72, 'Count': 713}
# {'_id': 73, 'Count': 713}
# {'_id': 74, 'Count': 713}
# {'_id': 75, 'Count': 713}
# {'_id': 76, 'Count': 713}
# {'_id': 77, 'Count': 713}
# {'_id': 78, 'Count': 713}
# {'_id': 79, 'Count': 713}
# {'_id': 80, 'Count': 713}
# {'_id': 81, 'Count': 713}
# {'_id': 82, 'Count': 713}
# {'_id': 83, 'Count': 713}
# {'_id': 84, 'Count': 713}
# {'_id': 85, 'Count': 713}
# {'_id': 86, 'Count': 713}
# {'_id': 87, 'Count': 713}
# {'_id': 88, 'Count': 713}
# {'_id': 89, 'Count': 713}
# {'_id': 90, 'Count': 713}
# {'_id': 91, 'Count': 713}
# {'_id': 92, 'Count': 713}
# {'_id': 93, 'Count': 713}
# {'_id': 94, 'Count': 713}
# {'_id': 95, 'Count': 713}
# {'_id': 96, 'Count': 713}
# {'_id': 97, 'Count': 713}
# {'_id': 98, 'Count': 713}
# {'_id': 99, 'Count': 713}
# {'_id': 100, 'Count': 713}
# {'_id': 101, 'Count': 713}
# {'_id': 102, 'Count': 713}

# %%
# Filter records based on the condition - close more than open
count = db.stock.aggregate(
    [
        {
            '$match':{
                '$expr':{'$gt':['$close', '$open']}
            }
        },
        {
            '$group' : {
                '_id' : '$stock',
                'Count': {'$sum': 1}
            }
                #'close_minus_open': { '$subtract': [ '$close', '$open' ]  }
            
        },
        {
            '$sort': {'_id':1}
        },
#        { 
#            '$limit' : 20
#        }
    ]
)
# Print output
for doc in count :
    pp.pprint(doc)
# Out:
# {'_id': 0, 'Count': 409}
# {'_id': 1, 'Count': 601}
# {'_id': 2, 'Count': 510}
# {'_id': 3, 'Count': 499}
# {'_id': 4, 'Count': 366}
# {'_id': 5, 'Count': 400}
# {'_id': 6, 'Count': 516}
# {'_id': 7, 'Count': 475}
# {'_id': 8, 'Count': 476}
# {'_id': 9, 'Count': 384}
# {'_id': 10, 'Count': 449}
# {'_id': 11, 'Count': 534}
# {'_id': 12, 'Count': 400}
# {'_id': 13, 'Count': 461}
# {'_id': 14, 'Count': 629}
# {'_id': 15, 'Count': 689}
# {'_id': 16, 'Count': 447}
# {'_id': 17, 'Count': 670}
# {'_id': 18, 'Count': 500}
# {'_id': 19, 'Count': 486}
# {'_id': 20, 'Count': 448}
# {'_id': 21, 'Count': 482}
# {'_id': 22, 'Count': 475}
# {'_id': 23, 'Count': 514}
# {'_id': 24, 'Count': 645}
# {'_id': 25, 'Count': 429}
# {'_id': 26, 'Count': 452}
# {'_id': 27, 'Count': 375}
# {'_id': 28, 'Count': 433}
# {'_id': 29, 'Count': 525}
# {'_id': 30, 'Count': 493}
# {'_id': 31, 'Count': 417}
# {'_id': 32, 'Count': 505}
# {'_id': 33, 'Count': 461}
# {'_id': 34, 'Count': 546}
# {'_id': 35, 'Count': 467}
# {'_id': 36, 'Count': 392}
# {'_id': 37, 'Count': 626}
# {'_id': 38, 'Count': 479}
# {'_id': 39, 'Count': 409}
# {'_id': 40, 'Count': 477}
# {'_id': 41, 'Count': 438}
# {'_id': 42, 'Count': 394}
# {'_id': 43, 'Count': 511}
# {'_id': 44, 'Count': 529}
# {'_id': 45, 'Count': 427}
# {'_id': 46, 'Count': 412}
# {'_id': 47, 'Count': 509}
# {'_id': 48, 'Count': 518}
# {'_id': 49, 'Count': 457}
# {'_id': 50, 'Count': 402}
# {'_id': 51, 'Count': 675}
# {'_id': 52, 'Count': 406}
# {'_id': 53, 'Count': 436}
# {'_id': 54, 'Count': 379}
# {'_id': 55, 'Count': 420}
# {'_id': 56, 'Count': 467}
# {'_id': 57, 'Count': 452}
# {'_id': 58, 'Count': 400}
# {'_id': 59, 'Count': 548}
# {'_id': 60, 'Count': 423}
# {'_id': 61, 'Count': 410}
# {'_id': 62, 'Count': 450}
# {'_id': 63, 'Count': 456}
# {'_id': 64, 'Count': 477}
# {'_id': 65, 'Count': 411}
# {'_id': 66, 'Count': 394}
# {'_id': 67, 'Count': 713}
# {'_id': 68, 'Count': 387}
# {'_id': 69, 'Count': 429}
# {'_id': 70, 'Count': 671}
# {'_id': 71, 'Count': 551}
# {'_id': 72, 'Count': 479}
# {'_id': 73, 'Count': 512}
# {'_id': 74, 'Count': 416}
# {'_id': 75, 'Count': 421}
# {'_id': 76, 'Count': 562}
# {'_id': 77, 'Count': 371}
# {'_id': 78, 'Count': 513}
# {'_id': 79, 'Count': 449}
# {'_id': 80, 'Count': 391}
# {'_id': 81, 'Count': 700}
# {'_id': 82, 'Count': 568}
# {'_id': 83, 'Count': 500}
# {'_id': 84, 'Count': 464}
# {'_id': 85, 'Count': 386}
# {'_id': 86, 'Count': 394}
# {'_id': 87, 'Count': 471}
# {'_id': 88, 'Count': 422}
# {'_id': 89, 'Count': 433}
# {'_id': 90, 'Count': 433}
# {'_id': 91, 'Count': 397}
# {'_id': 92, 'Count': 385}
# {'_id': 93, 'Count': 372}
# {'_id': 94, 'Count': 513}
# {'_id': 95, 'Count': 397}
# {'_id': 96, 'Count': 396}
# {'_id': 97, 'Count': 385}
# {'_id': 98, 'Count': 384}
# {'_id': 99, 'Count': 384}
# {'_id': 100, 'Count': 486}
# {'_id': 101, 'Count': 363}
# {'_id': 102, 'Count': 440}

# %%
# Just to validate 
# Filter records based on the condition - opposite to the above - close less than open
count = db.stock.aggregate(
    [
        {
            '$match':{
                '$expr':{'$lt':['$close', '$open']}
            }
        },
        {
            '$group' : {
                '_id' : '$stock',
                'Count': {'$sum': 1}
            }
                #'close_minus_open': { '$subtract': [ '$close', '$open' ]  }
            
        },
        {
            '$sort': {'_id':1}
        },
#         { 
#             '$limit' : 20
#         }
    ]
)
# Print output
for doc in count :
    pp.pprint(doc)
# Out:
# {'_id': 0, 'Count': 304}
# {'_id': 1, 'Count': 112}
# {'_id': 2, 'Count': 203}
# {'_id': 3, 'Count': 214}
# {'_id': 4, 'Count': 347}
# {'_id': 5, 'Count': 313}
# {'_id': 6, 'Count': 197}
# {'_id': 7, 'Count': 238}
# {'_id': 8, 'Count': 237}
# {'_id': 9, 'Count': 329}
# {'_id': 10, 'Count': 264}
# {'_id': 11, 'Count': 179}
# {'_id': 12, 'Count': 313}
# {'_id': 13, 'Count': 252}
# {'_id': 14, 'Count': 84}
# {'_id': 15, 'Count': 24}
# {'_id': 16, 'Count': 266}
# {'_id': 17, 'Count': 43}
# {'_id': 18, 'Count': 213}
# {'_id': 19, 'Count': 227}
# {'_id': 20, 'Count': 265}
# {'_id': 21, 'Count': 231}
# {'_id': 22, 'Count': 238}
# {'_id': 23, 'Count': 199}
# {'_id': 24, 'Count': 68}
# {'_id': 25, 'Count': 282}
# {'_id': 26, 'Count': 261}
# {'_id': 27, 'Count': 338}
# {'_id': 28, 'Count': 280}
# {'_id': 29, 'Count': 187}
# {'_id': 30, 'Count': 220}
# {'_id': 31, 'Count': 296}
# {'_id': 32, 'Count': 208}
# {'_id': 33, 'Count': 252}
# {'_id': 34, 'Count': 167}
# {'_id': 35, 'Count': 246}
# {'_id': 36, 'Count': 321}
# {'_id': 37, 'Count': 87}
# {'_id': 38, 'Count': 234}
# {'_id': 39, 'Count': 304}
# {'_id': 40, 'Count': 236}
# {'_id': 41, 'Count': 275}
# {'_id': 42, 'Count': 319}
# {'_id': 43, 'Count': 202}
# {'_id': 44, 'Count': 184}
# {'_id': 45, 'Count': 286}
# {'_id': 46, 'Count': 301}
# {'_id': 47, 'Count': 204}
# {'_id': 48, 'Count': 195}
# {'_id': 49, 'Count': 256}
# {'_id': 50, 'Count': 311}
# {'_id': 51, 'Count': 38}
# {'_id': 52, 'Count': 307}
# {'_id': 53, 'Count': 277}
# {'_id': 54, 'Count': 334}
# {'_id': 55, 'Count': 293}
# {'_id': 56, 'Count': 246}
# {'_id': 57, 'Count': 261}
# {'_id': 58, 'Count': 313}
# {'_id': 59, 'Count': 165}
# {'_id': 60, 'Count': 290}
# {'_id': 61, 'Count': 303}
# {'_id': 62, 'Count': 262}
# {'_id': 63, 'Count': 257}
# {'_id': 64, 'Count': 236}
# {'_id': 65, 'Count': 302}
# {'_id': 66, 'Count': 319}
# {'_id': 68, 'Count': 326}
# {'_id': 69, 'Count': 284}
# {'_id': 70, 'Count': 42}
# {'_id': 71, 'Count': 162}
# {'_id': 72, 'Count': 233}
# {'_id': 73, 'Count': 201}
# {'_id': 74, 'Count': 297}
# {'_id': 75, 'Count': 292}
# {'_id': 76, 'Count': 150}
# {'_id': 77, 'Count': 341}
# {'_id': 78, 'Count': 199}
# {'_id': 79, 'Count': 264}
# {'_id': 80, 'Count': 322}
# {'_id': 81, 'Count': 13}
# {'_id': 82, 'Count': 145}
# {'_id': 83, 'Count': 213}
# {'_id': 84, 'Count': 249}
# {'_id': 85, 'Count': 327}
# {'_id': 86, 'Count': 319}
# {'_id': 87, 'Count': 242}
# {'_id': 88, 'Count': 291}
# {'_id': 89, 'Count': 280}
# {'_id': 90, 'Count': 280}
# {'_id': 91, 'Count': 316}
# {'_id': 92, 'Count': 328}
# {'_id': 93, 'Count': 341}
# {'_id': 94, 'Count': 200}
# {'_id': 95, 'Count': 316}
# {'_id': 96, 'Count': 317}
# {'_id': 97, 'Count': 328}
# {'_id': 98, 'Count': 329}
# {'_id': 99, 'Count': 329}
# {'_id': 100, 'Count': 227}
# {'_id': 101, 'Count': 350}
# {'_id': 102, 'Count': 273}

# %% [markdown]
# ### Q4
#
# Find average `open` price, using all the stocks, for each of the following -
#
# - for each year. Ex - for 2017, 2018, etc.
#
# ![](Images/shot_1.png)
#
# - for every month of each year. Ex - for January 2017, February 2017, etc.
#
# ![](Images/shot_2.png)
#
# - for every week of each year. Ex - for Week 1 2017, Week 2 2017, etc.
#
# ![](Images/shot_3.png)
#
# ***Hint - Use a single pipeline to answer the above query.***

# %%
result = db.stock.aggregate(
    
    # Pipeline
    [
        # Stage 1 - Project year and month
        {
            '$project':{
                            'Year':{'$year':'$date'},
                            'Month':{'$month':'$date'},
                            'Week' :{'$week':'$date'},
                            'stock':1,
                            'open':1
                        }
        },
        
        # Stage 2 - Sub-pipelines
        {
            '$facet':{
                        # Sub-pipeline 1 - Aggregate along year
                        'Yearly_avg_open':[
                                                # Stage 1 - Group
                                                {
                                                    '$group':{
                                                                '_id':'$Year',
                                                                'avg_open_price':{'$avg':'$open'}
                                                            }
                                                },
                                                # Stage 2 - Sort
                                                {
                                                    '$sort':{'_id':1}
                                                }
                                         ],
                
                        # Sub-pipeline 2 - Aggregate along month
                        'Monthly_avg_price':[
                                                # Stage 1 - Group
                                                {
                                                    '$group':{
                                                                '_id':{
                                                                         'Year':'$Year',
                                                                          'Month':'$Month'
                                                                      },
                                                                'avg_open_price':{'$avg':'$open'}
                                                            }
                                                },
                                                # Stage 2 - Sort
                                                {
                                                    '$sort':{'_id':1}
                                                }
                                         ] ,
                        # Sub-pipeline 3 - Aggregate along week
                        'weekly_avg_open':[
                                                # Stage 1 - Group
                                                {
                                                    '$group':{
                                                                '_id':{
                                                                         'Year':'$Year',
                                                                          #'Month':'$Month',
                                                                          'Week':'$Week'
                                                                      },
                                                                'avg_open_price':{'$avg':'$open'}
                                                            }
                                                },
                                                # Stage 2 - Sort
                                                {
                                                    '$sort':{'_id':1}
                                                }
                                         ] 

                        }
            }
    ])

# Print results
for doc in result:
    pp.pprint(doc)
# Out:
# {'Yearly_avg_open': [{'_id': 2017, 'avg_open_price': 70.74269854562333},
#                      {'_id': 2018, 'avg_open_price': 77.16022568367308},
#                      {'_id': 2019, 'avg_open_price': 78.8781701421801}],
#  'Monthly_avg_price': [{'_id': {'Year': 2017, 'Month': 1},
#                         'avg_open_price': 65.5625404368932},
#                        {'_id': {'Year': 2017, 'Month': 2},
#                         'avg_open_price': 66.84547455288707},
#                        {'_id': {'Year': 2017, 'Month': 3},
#                         'avg_open_price': 67.40347053609118},
#                        {'_id': {'Year': 2017, 'Month': 4},
#                         'avg_open_price': 67.89529882473173},
#                        {'_id': {'Year': 2017, 'Month': 5},
#                         'avg_open_price': 69.4015865842895},
#                        {'_id': {'Year': 2017, 'Month': 6},
#                         'avg_open_price': 70.34023137687555},
#                        {'_id': {'Year': 2017, 'Month': 7},
#                         'avg_open_price': 71.28731912621359},
#                        {'_id': {'Year': 2017, 'Month': 8},
#                         'avg_open_price': 71.46239653862389},
#                        {'_id': {'Year': 2017, 'Month': 9},
#                         'avg_open_price': 72.74031208737864},
#                        {'_id': {'Year': 2017, 'Month': 10},
#                         'avg_open_price': 74.17840816416593},
#                        {'_id': {'Year': 2017, 'Month': 11},
#                         'avg_open_price': 74.89591613499769},
#                        {'_id': {'Year': 2017, 'Month': 12},
#                         'avg_open_price': 76.57825257281553},
#                        {'_id': {'Year': 2018, 'Month': 1},
#                         'avg_open_price': 80.09390818307907},
#                        {'_id': {'Year': 2018, 'Month': 2},
#                         'avg_open_price': 77.4085183444047},
#                        {'_id': {'Year': 2018, 'Month': 3},
#                         'avg_open_price': 77.49350624133149},
#                        {'_id': {'Year': 2018, 'Month': 4},
#                         'avg_open_price': 77.05129241793804},
#                        {'_id': {'Year': 2018, 'Month': 5},
#                         'avg_open_price': 77.4696341129744},
#                        {'_id': {'Year': 2018, 'Month': 6},
#                         'avg_open_price': 77.9115108183079},
#                        {'_id': {'Year': 2018, 'Month': 7},
#                         'avg_open_price': 77.82225852981969},
#                        {'_id': {'Year': 2018, 'Month': 8},
#                         'avg_open_price': 78.6744989024905},
#                        {'_id': {'Year': 2018, 'Month': 9},
#                         'avg_open_price': 79.06422089933572},
#                        {'_id': {'Year': 2018, 'Month': 10},
#                         'avg_open_price': 75.90132258336851},
#                        {'_id': {'Year': 2018, 'Month': 11},
#                         'avg_open_price': 74.72502427184466},
#                        {'_id': {'Year': 2018, 'Month': 12},
#                         'avg_open_price': 71.97953929483904},
#                        {'_id': {'Year': 2019, 'Month': 1},
#                         'avg_open_price': 73.34111363846509},
#                        {'_id': {'Year': 2019, 'Month': 2},
#                         'avg_open_price': 76.91665416453756},
#                        {'_id': {'Year': 2019, 'Month': 3},
#                         'avg_open_price': 78.13186375404531},
#                        {'_id': {'Year': 2019, 'Month': 4},
#                         'avg_open_price': 80.22327951918632},
#                        {'_id': {'Year': 2019, 'Month': 5},
#                         'avg_open_price': 78.03521094439542},
#                        {'_id': {'Year': 2019, 'Month': 6},
#                         'avg_open_price': 79.01449296116505},
#                        {'_id': {'Year': 2019, 'Month': 7},
#                         'avg_open_price': 81.44466743159752},
#                        {'_id': {'Year': 2019, 'Month': 8},
#                         'avg_open_price': 79.00798503971755},
#                        {'_id': {'Year': 2019, 'Month': 9},
#                         'avg_open_price': 81.19135752427184},
#                        {'_id': {'Year': 2019, 'Month': 10},
#                         'avg_open_price': 81.10461177712115}],
#  'weekly_avg_open': [{'_id': {'Year': 2017, 'Week': 1},
#                       'avg_open_price': 64.9749286407767},
#                      {'_id': {'Year': 2017, 'Week': 2},
#                       'avg_open_price': 65.2441504854369},
#                      {'_id': {'Year': 2017, 'Week': 3},
#                       'avg_open_price': 65.48754927184466},
#                      {'_id': {'Year': 2017, 'Week': 4},
#                       'avg_open_price': 66.17018834951456},
#                      {'_id': {'Year': 2017, 'Week': 5},
#                       'avg_open_price': 66.27644000000001},
#                      {'_id': {'Year': 2017, 'Week': 6},
#                       'avg_open_price': 66.31179009708738},
#                      {'_id': {'Year': 2017, 'Week': 7},
#                       'avg_open_price': 67.0488363106796},
#                      {'_id': {'Year': 2017, 'Week': 8},
#                       'avg_open_price': 67.4082245145631},
#                      {'_id': {'Year': 2017, 'Week': 9},
#                       'avg_open_price': 67.46620077669903},
#                      {'_id': {'Year': 2017, 'Week': 10},
#                       'avg_open_price': 67.09726699029126},
#                      {'_id': {'Year': 2017, 'Week': 11},
#                       'avg_open_price': 67.44023980582524},
#                      {'_id': {'Year': 2017, 'Week': 12},
#                       'avg_open_price': 67.48384970873786},
#                      {'_id': {'Year': 2017, 'Week': 13},
#                       'avg_open_price': 67.48340504854369},
#                      {'_id': {'Year': 2017, 'Week': 14},
#                       'avg_open_price': 67.68078485436894},
#                      {'_id': {'Year': 2017, 'Week': 15},
#                       'avg_open_price': 67.53324441747573},
#                      {'_id': {'Year': 2017, 'Week': 16},
#                       'avg_open_price': 67.49570058252426},
#                      {'_id': {'Year': 2017, 'Week': 17},
#                       'avg_open_price': 68.7990545631068},
#                      {'_id': {'Year': 2017, 'Week': 18},
#                       'avg_open_price': 68.97475106796117},
#                      {'_id': {'Year': 2017, 'Week': 19},
#                       'avg_open_price': 69.21368834951457},
#                      {'_id': {'Year': 2017, 'Week': 20},
#                       'avg_open_price': 69.36456718446601},
#                      {'_id': {'Year': 2017, 'Week': 21},
#                       'avg_open_price': 69.84390621359223},
#                      {'_id': {'Year': 2017, 'Week': 22},
#                       'avg_open_price': 70.08405242718446},
#                      {'_id': {'Year': 2017, 'Week': 23},
#                       'avg_open_price': 70.33277766990291},
#                      {'_id': {'Year': 2017, 'Week': 24},
#                       'avg_open_price': 70.24046660194175},
#                      {'_id': {'Year': 2017, 'Week': 25},
#                       'avg_open_price': 70.27736213592233},
#                      {'_id': {'Year': 2017, 'Week': 26},
#                       'avg_open_price': 70.54923786407767},
#                      {'_id': {'Year': 2017, 'Week': 27},
#                       'avg_open_price': 70.50145072815533},
#                      {'_id': {'Year': 2017, 'Week': 28},
#                       'avg_open_price': 70.89005805825242},
#                      {'_id': {'Year': 2017, 'Week': 29},
#                       'avg_open_price': 71.61761514563106},
#                      {'_id': {'Year': 2017, 'Week': 30},
#                       'avg_open_price': 71.86885902912621},
#                      {'_id': {'Year': 2017, 'Week': 31},
#                       'avg_open_price': 71.96281106796116},
#                      {'_id': {'Year': 2017, 'Week': 32},
#                       'avg_open_price': 71.55453145631068},
#                      {'_id': {'Year': 2017, 'Week': 33},
#                       'avg_open_price': 71.25971747572817},
#                      {'_id': {'Year': 2017, 'Week': 34},
#                       'avg_open_price': 71.11519165048544},
#                      {'_id': {'Year': 2017, 'Week': 35},
#                       'avg_open_price': 71.62860757281554},
#                      {'_id': {'Year': 2017, 'Week': 36},
#                       'avg_open_price': 72.19249563106796},
#                      {'_id': {'Year': 2017, 'Week': 37},
#                       'avg_open_price': 72.7916623300971},
#                      {'_id': {'Year': 2017, 'Week': 38},
#                       'avg_open_price': 73.02663262135923},
#                      {'_id': {'Year': 2017, 'Week': 39},
#                       'avg_open_price': 72.9667054368932},
#                      {'_id': {'Year': 2017, 'Week': 40},
#                       'avg_open_price': 73.75777436893203},
#                      {'_id': {'Year': 2017, 'Week': 41},
#                       'avg_open_price': 74.16347805825242},
#                      {'_id': {'Year': 2017, 'Week': 42},
#                       'avg_open_price': 74.39064854368932},
#                      {'_id': {'Year': 2017, 'Week': 43},
#                       'avg_open_price': 74.3536990291262},
#                      {'_id': {'Year': 2017, 'Week': 44},
#                       'avg_open_price': 74.50770058252427},
#                      {'_id': {'Year': 2017, 'Week': 45},
#                       'avg_open_price': 74.55340271844659},
#                      {'_id': {'Year': 2017, 'Week': 46},
#                       'avg_open_price': 74.36176563106797},
#                      {'_id': {'Year': 2017, 'Week': 47},
#                       'avg_open_price': 75.29969174757282},
#                      {'_id': {'Year': 2017, 'Week': 48},
#                       'avg_open_price': 75.83023242718447},
#                      {'_id': {'Year': 2017, 'Week': 49},
#                       'avg_open_price': 75.88367611650486},
#                      {'_id': {'Year': 2017, 'Week': 50},
#                       'avg_open_price': 76.21256155339806},
#                      {'_id': {'Year': 2017, 'Week': 51},
#                       'avg_open_price': 77.06772524271844},
#                      {'_id': {'Year': 2017, 'Week': 52},
#                       'avg_open_price': 77.42304538834951},
#                      {'_id': {'Year': 2018, 'Week': 0},
#                       'avg_open_price': 78.32236893203883},
#                      {'_id': {'Year': 2018, 'Week': 1},
#                       'avg_open_price': 79.23232621359223},
#                      {'_id': {'Year': 2018, 'Week': 2},
#                       'avg_open_price': 80.39544417475729},
#                      {'_id': {'Year': 2018, 'Week': 3},
#                       'avg_open_price': 81.50220427184466},
#                      {'_id': {'Year': 2018, 'Week': 4},
#                       'avg_open_price': 80.79136368932039},
#                      {'_id': {'Year': 2018, 'Week': 5},
#                       'avg_open_price': 76.6036345631068},
#                      {'_id': {'Year': 2018, 'Week': 6},
#                       'avg_open_price': 76.47570194174757},
#                      {'_id': {'Year': 2018, 'Week': 7},
#                       'avg_open_price': 77.5343995145631},
#                      {'_id': {'Year': 2018, 'Week': 8},
#                       'avg_open_price': 77.55920291262136},
#                      {'_id': {'Year': 2018, 'Week': 9},
#                       'avg_open_price': 77.6384759223301},
#                      {'_id': {'Year': 2018, 'Week': 10},
#                       'avg_open_price': 78.68713611650485},
#                      {'_id': {'Year': 2018, 'Week': 11},
#                       'avg_open_price': 77.48131009708737},
#                      {'_id': {'Year': 2018, 'Week': 12},
#                       'avg_open_price': 76.30798058252427},
#                      {'_id': {'Year': 2018, 'Week': 13},
#                       'avg_open_price': 76.19218038834951},
#                      {'_id': {'Year': 2018, 'Week': 14},
#                       'avg_open_price': 76.9833403883495},
#                      {'_id': {'Year': 2018, 'Week': 15},
#                       'avg_open_price': 77.83785436893204},
#                      {'_id': {'Year': 2018, 'Week': 16},
#                       'avg_open_price': 77.16665553398057},
#                      {'_id': {'Year': 2018, 'Week': 17},
#                       'avg_open_price': 76.59368310679612},
#                      {'_id': {'Year': 2018, 'Week': 18},
#                       'avg_open_price': 77.44611359223302},
#                      {'_id': {'Year': 2018, 'Week': 19},
#                       'avg_open_price': 78.01531941747572},
#                      {'_id': {'Year': 2018, 'Week': 20},
#                       'avg_open_price': 77.92066116504854},
#                      {'_id': {'Year': 2018, 'Week': 21},
#                       'avg_open_price': 77.30695097087379},
#                      {'_id': {'Year': 2018, 'Week': 22},
#                       'avg_open_price': 78.41215553398058},
#                      {'_id': {'Year': 2018, 'Week': 23},
#                       'avg_open_price': 78.80264233009709},
#                      {'_id': {'Year': 2018, 'Week': 24},
#                       'avg_open_price': 77.83060854368932},
#                      {'_id': {'Year': 2018, 'Week': 25},
#                       'avg_open_price': 76.66338854368932},
#                      {'_id': {'Year': 2018, 'Week': 26},
#                       'avg_open_price': 76.53403713592233},
#                      {'_id': {'Year': 2018, 'Week': 27},
#                       'avg_open_price': 77.69448427184466},
#                      {'_id': {'Year': 2018, 'Week': 28},
#                       'avg_open_price': 77.94763087378641},
#                      {'_id': {'Year': 2018, 'Week': 29},
#                       'avg_open_price': 78.50931883495146},
#                      {'_id': {'Year': 2018, 'Week': 30},
#                       'avg_open_price': 78.57494097087378},
#                      {'_id': {'Year': 2018, 'Week': 31},
#                       'avg_open_price': 78.82487980582525},
#                      {'_id': {'Year': 2018, 'Week': 32},
#                       'avg_open_price': 77.69801145631068},
#                      {'_id': {'Year': 2018, 'Week': 33},
#                       'avg_open_price': 78.70817436893203},
#                      {'_id': {'Year': 2018, 'Week': 34},
#                       'avg_open_price': 79.57151048543689},
#                      {'_id': {'Year': 2018, 'Week': 35},
#                       'avg_open_price': 78.66073179611651},
#                      {'_id': {'Year': 2018, 'Week': 36},
#                       'avg_open_price': 78.57774699029126},
#                      {'_id': {'Year': 2018, 'Week': 37},
#                       'avg_open_price': 79.42493165048543},
#                      {'_id': {'Year': 2018, 'Week': 38},
#                       'avg_open_price': 79.51277533980583},
#                      {'_id': {'Year': 2018, 'Week': 39},
#                       'avg_open_price': 78.87464058252426},
#                      {'_id': {'Year': 2018, 'Week': 40},
#                       'avg_open_price': 76.52050524271844},
#                      {'_id': {'Year': 2018, 'Week': 41},
#                       'avg_open_price': 75.62602737864077},
#                      {'_id': {'Year': 2018, 'Week': 42},
#                       'avg_open_price': 73.9844732038835},
#                      {'_id': {'Year': 2018, 'Week': 43},
#                       'avg_open_price': 74.12899533980583},
#                      {'_id': {'Year': 2018, 'Week': 44},
#                       'avg_open_price': 75.59726174757282},
#                      {'_id': {'Year': 2018, 'Week': 45},
#                       'avg_open_price': 74.81388660194175},
#                      {'_id': {'Year': 2018, 'Week': 46},
#                       'avg_open_price': 73.88780558252428},
#                      {'_id': {'Year': 2018, 'Week': 47},
#                       'avg_open_price': 74.33515126213592},
#                      {'_id': {'Year': 2018, 'Week': 48},
#                       'avg_open_price': 74.69030024271845},
#                      {'_id': {'Year': 2018, 'Week': 49},
#                       'avg_open_price': 73.16356951456311},
#                      {'_id': {'Year': 2018, 'Week': 50},
#                       'avg_open_price': 71.16623572815534},
#                      {'_id': {'Year': 2018, 'Week': 51},
#                       'avg_open_price': 69.14936529126213},
#                      {'_id': {'Year': 2018, 'Week': 52},
#                       'avg_open_price': 70.60355825242719},
#                      {'_id': {'Year': 2019, 'Week': 0},
#                       'avg_open_price': 70.40226051779935},
#                      {'_id': {'Year': 2019, 'Week': 1},
#                       'avg_open_price': 72.78185844660193},
#                      {'_id': {'Year': 2019, 'Week': 2},
#                       'avg_open_price': 73.60728834951456},
#                      {'_id': {'Year': 2019, 'Week': 3},
#                       'avg_open_price': 74.38231699029126},
#                      {'_id': {'Year': 2019, 'Week': 4},
#                       'avg_open_price': 75.04199067961166},
#                      {'_id': {'Year': 2019, 'Week': 5},
#                       'avg_open_price': 75.94143980582524},
#                      {'_id': {'Year': 2019, 'Week': 6},
#                       'avg_open_price': 76.42505883495146},
#                      {'_id': {'Year': 2019, 'Week': 7},
#                       'avg_open_price': 77.674861407767},
#                      {'_id': {'Year': 2019, 'Week': 8},
#                       'avg_open_price': 78.30046},
#                      {'_id': {'Year': 2019, 'Week': 9},
#                       'avg_open_price': 77.64476485436893},
#                      {'_id': {'Year': 2019, 'Week': 10},
#                       'avg_open_price': 77.79658563106797},
#                      {'_id': {'Year': 2019, 'Week': 11},
#                       'avg_open_price': 78.80520116504854},
#                      {'_id': {'Year': 2019, 'Week': 12},
#                       'avg_open_price': 78.23804407766991},
#                      {'_id': {'Year': 2019, 'Week': 13},
#                       'avg_open_price': 79.73374601941748},
#                      {'_id': {'Year': 2019, 'Week': 14},
#                       'avg_open_price': 80.27092893203884},
#                      {'_id': {'Year': 2019, 'Week': 15},
#                       'avg_open_price': 80.7211791262136},
#                      {'_id': {'Year': 2019, 'Week': 16},
#                       'avg_open_price': 80.24924135922329},
#                      {'_id': {'Year': 2019, 'Week': 17},
#                       'avg_open_price': 80.12974194174757},
#                      {'_id': {'Year': 2019, 'Week': 18},
#                       'avg_open_price': 78.6349545631068},
#                      {'_id': {'Year': 2019, 'Week': 19},
#                       'avg_open_price': 77.7990427184466},
#                      {'_id': {'Year': 2019, 'Week': 20},
#                       'avg_open_price': 77.63372427184467},
#                      {'_id': {'Year': 2019, 'Week': 21},
#                       'avg_open_price': 76.58047378640777},
#                      {'_id': {'Year': 2019, 'Week': 22},
#                       'avg_open_price': 77.39824932038836},
#                      {'_id': {'Year': 2019, 'Week': 23},
#                       'avg_open_price': 78.92496368932039},
#                      {'_id': {'Year': 2019, 'Week': 24},
#                       'avg_open_price': 79.59085708737864},
#                      {'_id': {'Year': 2019, 'Week': 25},
#                       'avg_open_price': 80.14390174757281},
#                      {'_id': {'Year': 2019, 'Week': 26},
#                       'avg_open_price': 81.37972864077669},
#                      {'_id': {'Year': 2019, 'Week': 27},
#                       'avg_open_price': 81.2187},
#                      {'_id': {'Year': 2019, 'Week': 28},
#                       'avg_open_price': 81.50390155339805},
#                      {'_id': {'Year': 2019, 'Week': 29},
#                       'avg_open_price': 81.56142058252428},
#                      {'_id': {'Year': 2019, 'Week': 30},
#                       'avg_open_price': 81.15725378640776},
#                      {'_id': {'Year': 2019, 'Week': 31},
#                       'avg_open_price': 78.73218349514563},
#                      {'_id': {'Year': 2019, 'Week': 32},
#                       'avg_open_price': 78.37721126213593},
#                      {'_id': {'Year': 2019, 'Week': 33},
#                       'avg_open_price': 79.33106563106796},
#                      {'_id': {'Year': 2019, 'Week': 34},
#                       'avg_open_price': 79.00615165048544},
#                      {'_id': {'Year': 2019, 'Week': 35},
#                       'avg_open_price': 80.23918616504854},
#                      {'_id': {'Year': 2019, 'Week': 36},
#                       'avg_open_price': 81.47730466019418},
#                      {'_id': {'Year': 2019, 'Week': 37},
#                       'avg_open_price': 81.7156050485437},
#                      {'_id': {'Year': 2019, 'Week': 38},
#                       'avg_open_price': 81.21326194174756},
#                      {'_id': {'Year': 2019, 'Week': 39},
#                       'avg_open_price': 80.03598368932039},
#                      {'_id': {'Year': 2019, 'Week': 40},
#                       'avg_open_price': 79.94576194174758},
#                      {'_id': {'Year': 2019, 'Week': 41},
#                       'avg_open_price': 81.30497747572815},
#                      {'_id': {'Year': 2019, 'Week': 42},
#                       'avg_open_price': 81.98920368932038},
#                      {'_id': {'Year': 2019, 'Week': 43},
#                       'avg_open_price': 82.46649611650486}]}

# %% [markdown]
# ### Q5
#
# Find the number of stocks that have `high` price in the groups [0, 50), [50, 100), [100, 200) and [200, 400).
#
# ***Note - [ means value is included. And ) means that the value is excluded.***

# %%
# Enter your code here
cur = db.stock.aggregate(
        [ 
        # Stage 1 - Project 
        {
            '$project':{
                            '_id':0,
                            'stock':1,
                            'open':1
                        }
        },
        
        # Stage 2 - bucket and count
            { 
                '$bucket' :{
                    # Group by condition
                    'groupBy' : '$open' ,
                    # Bucket boundaries
                    'boundaries':[0,50,100,200,400],
                    #operation
                    'output':{
                        'Count':{'$sum':1}
                    }
                }
            }
        ]
)
# Print docs
for doc in cur :
    pp.pprint(doc)
# Out:
# {'_id': 0, 'Count': 18336}
# {'_id': 50, 'Count': 40207}
# {'_id': 100, 'Count': 14784}
# {'_id': 200, 'Count': 112}

# %% [markdown]
# ### Q6
#
# Count the number of holidays.

# %%
count = db.stock.aggregate(
    [
        {
            '$match': {
                'holiday': {'$eq': 1}}
        },
        {
            '$count': "number of holidays"
        }
    ]
)
# Print output
for doc in count :
    pp.pprint(doc)
# Out:
# {'number of holidays': 4223}
