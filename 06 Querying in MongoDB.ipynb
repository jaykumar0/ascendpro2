# %% [markdown]
# ### Problem statement
#
# The data is related to a coding platform that hosts coding challenges. They have a unique business model, where they crowdsource problems from various creators(authors). These authors create the problem and release it on the client's platform. The users then select the challenges they want to solve.
#
# This dataset contains information about each coding problem. It contains information about the problem, about the author who created it and a list of users who have attempted the problem.
#
# Below are the fields that can be founf within each document in the collection -
#
# - `challenge_id` - Unique id of the challenge problem
#
# - `programming_language` - Programming language for the challenge
#
# - `total_submissions` - Total submissions by all users
#
# - `publish_date` - Publishing date for the challenge
#
# - `author` - Embedded document about the author of the challenge.
# > - `id` - Author id
# > - `gender` - Author gender
# > - `org_id` - Organisation if for author
#
# - `users` - List of users who have attempted the challenge
#
# ----

# %% [markdown]
# ### Connecting to MongoDB
#
#
# ----

# %%
# Importing the required libraries
import pymongo
import pprint as pp


pp.sorted = lambda x, key=None: x

# %%
client = pymongo.MongoClient("mongodb://localhost:27017/")

# %% [markdown]
# ---
# ### Importing data
#
# ----

# %%
# # Restore database
# !mongorestore /home/avadmin/Desktop/Mongo/Content/Querying/Assignment/Data/querying_assignment

# %%
# List databases
client.list_database_names()
# Out:
# ['admin', 'av', 'config', 'local', 'sample', 'sample_analytics']

# %%
db = client['av']

# %%
db.list_collection_names()
# Out:
# ['demo_csv', 'challenge']

# %%
pp.pprint(
    db.challenge.find_one()
)
# Out:
# {'_id': ObjectId('60dab9f75945974466d8d64d'),
#  'challenge_id': 'CI23478',
#  'programming_language': 2,
#  'total_submissions': 37,
#  'publish_date': datetime.datetime(2006, 6, 5, 0, 0),
#  'author': {'id': 'AI563576', 'gender': 'M', 'org_id': 'AOI100001'},
#  'users': [32876, 88820, 97150, 97359]}

# %% [markdown]
# ---
# ### Assignment Questions
#
# ----

# %% [markdown]
# ### Q1.
#
# Find the number of documents in the collection

# %%
db.challenge.count_documents({})
# Out:
# 5606

# %% [markdown]
# ### Q2.
#
# Find the number of unique `programming_language` and `challenge_id`

# %%
db.challenge.distinct('programming_language')
# Out:
# [1, 2, 3]

# %%
len(db.challenge.distinct('programming_language'))
# Out:
# 3

# %%
len(db.challenge.distinct('challenge_id'))
# Out:
# 5606

# %% [markdown]
# ### Q3.
#
# How many documents are there where the challenge was created between `2009-01-01` and `2010-01-01`?

# %%
# Import datetime lib
from datetime import datetime

# %%
cur = db.challenge.find(
    # query expression
    {
        'publish_date':{'$gte':datetime(2009,1,1),'$lte':datetime(2010,1,1)}
    },
    # projection
    {
        'publish_date':1,
        'programming_language':1,
        '_id':0
    })
# Print docs
for doc in cur :
    pp.pprint(doc)
# Out:
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 1, 20, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 1, 20, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 1, 20, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 1, 20, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 1, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 1, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 1, 27, 0, 0)}
# {'programming_language': 2,
#  'publish_date': datetime.datetime(2009, 1, 31, 0, 0)}
# {'programming_language': 2,
#  'publish_date': datetime.datetime(2009, 1, 30, 0, 0)}
# {'programming_language': 2,
#  'publish_date': datetime.datetime(2009, 1, 30, 0, 0)}
# {'programming_language': 2,
#  'publish_date': datetime.datetime(2009, 1, 30, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 6, 2, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 6, 2, 0, 0)}
# {'programming_language': 2, 'publish_date': datetime.datetime(2009, 6, 2, 0, 0)}
# {'programming_language': 2, 'publish_date': datetime.datetime(2009, 6, 2, 0, 0)}
# {'programming_language': 2, 'publish_date': datetime.datetime(2009, 6, 2, 0, 0)}
# {'programming_language': 2, 'publish_date': datetime.datetime(2009, 6, 2, 0, 0)}
# {'programming_language': 2, 'publish_date': datetime.datetime(2009, 6, 2, 0, 0)}
# {'programming_language': 2, 'publish_date': datetime.datetime(2009, 6, 2, 0, 0)}
# {'programming_language': 2, 'publish_date': datetime.datetime(2009, 6, 2, 0, 0)}
# {'programming_language': 2, 'publish_date': datetime.datetime(2009, 4, 2, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 1, 26, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 1, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 1, 28, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 1, 28, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 1, 29, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 1, 30, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 2, 2, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 3, 2, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 4, 2, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 6, 2, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 1, 26, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 1, 26, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 1, 28, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 1, 28, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 1, 29, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 1, 30, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 2, 2, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 2, 2, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 12, 2, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 12, 2, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 12, 2, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 12, 2, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 12, 2, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 12, 2, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 2, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 2, 0, 0)}
# {'programming_language': 2,
#  'publish_date': datetime.datetime(2009, 10, 2, 0, 0)}
# {'programming_language': 2,
#  'publish_date': datetime.datetime(2009, 3, 18, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 2, 3, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 2, 3, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 2, 3, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 3, 3, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 3, 3, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 3, 3, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 4, 3, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 4, 3, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 5, 3, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 5, 3, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 6, 3, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 6, 3, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 6, 3, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 5, 2, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 2, 2, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 3, 2, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 4, 2, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 5, 2, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 6, 2, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 2, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 12, 3, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 3, 0, 0)}
# {'programming_language': 2,
#  'publish_date': datetime.datetime(2009, 3, 31, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 1, 4, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 1, 4, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 1, 4, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 1, 4, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 1, 4, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 1, 4, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 1, 4, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 1, 4, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 1, 4, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 2, 4, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 2, 4, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 2, 4, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 2, 4, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 2, 4, 0, 0)}
# {'programming_language': 2, 'publish_date': datetime.datetime(2009, 7, 4, 0, 0)}
# {'programming_language': 2,
#  'publish_date': datetime.datetime(2009, 3, 28, 0, 0)}
# {'programming_language': 2,
#  'publish_date': datetime.datetime(2009, 3, 28, 0, 0)}
# {'programming_language': 2,
#  'publish_date': datetime.datetime(2009, 3, 28, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 3, 24, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 3, 24, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 2, 18, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 17, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 1, 4, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 1, 4, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 1, 4, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 1, 4, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 2, 4, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 2, 4, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 2, 4, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 2, 4, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 2, 4, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 2, 4, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 2, 4, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 3, 4, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 3, 4, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 3, 4, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 3, 4, 0, 0)}
# {'programming_language': 2,
#  'publish_date': datetime.datetime(2009, 3, 24, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 3, 26, 0, 0)}
# {'programming_language': 2,
#  'publish_date': datetime.datetime(2009, 3, 27, 0, 0)}
# {'programming_language': 2,
#  'publish_date': datetime.datetime(2009, 10, 4, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 3, 18, 0, 0)}
# {'programming_language': 2, 'publish_date': datetime.datetime(2009, 8, 5, 0, 0)}
# {'programming_language': 2, 'publish_date': datetime.datetime(2009, 8, 5, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 22, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 22, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 23, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 23, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 23, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 23, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 23, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 23, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 23, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 23, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 24, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 24, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 24, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 24, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 24, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 24, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 24, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 24, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 24, 0, 0)}
# {'programming_language': 2,
#  'publish_date': datetime.datetime(2009, 3, 31, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 13, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 21, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 21, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 21, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 21, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 21, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 21, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 21, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 21, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 21, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 21, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 21, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 21, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 21, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 21, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 21, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 21, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 20, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 23, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 27, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 1, 6, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 26, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 5, 26, 0, 0)}
# {'programming_language': 2,
#  'publish_date': datetime.datetime(2009, 3, 25, 0, 0)}
# {'programming_language': 2,
#  'publish_date': datetime.datetime(2009, 3, 25, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 12, 6, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 12, 6, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 12, 6, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 12, 6, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 4, 22, 0, 0)}
# {'programming_language': 2,
#  'publish_date': datetime.datetime(2009, 7, 16, 0, 0)}
# {'programming_language': 2,
#  'publish_date': datetime.datetime(2009, 7, 16, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 3, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 3, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 3, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 3, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 3, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 3, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 3, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 4, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 4, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 4, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 4, 7, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 7, 14, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 7, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 7, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 7, 14, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 7, 14, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 7, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 7, 17, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 7, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 7, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 7, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 7, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 7, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 7, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 7, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 7, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 7, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 7, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 7, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 12, 7, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 28, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 28, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 28, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 28, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 28, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 28, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 28, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 16, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 14, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 14, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 14, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 14, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 14, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 14, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 18, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 18, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 18, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 18, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 18, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 18, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 18, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 18, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 18, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 18, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 18, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 18, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 18, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 18, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 18, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 18, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 18, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 18, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 18, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 18, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 18, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 18, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 18, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 18, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 18, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 15, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 2, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 2, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 3, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 3, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 4, 7, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 3, 26, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 7, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 9, 14, 0, 0)}
# {'programming_language': 2,
#  'publish_date': datetime.datetime(2009, 3, 18, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 14, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 5, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 5, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 5, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 5, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 5, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 5, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 5, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 5, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 6, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 6, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 6, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 6, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 6, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 6, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 8, 30, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 8, 30, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 8, 30, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 8, 30, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 8, 31, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 8, 31, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 1, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 2, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 3, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 3, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 3, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 5, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 5, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 4, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 7, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 7, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 7, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 18, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 7, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 7, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 7, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 7, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 7, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 7, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 7, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 7, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 7, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 7, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 9, 29, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 9, 23, 0, 0)}
# {'programming_language': 2,
#  'publish_date': datetime.datetime(2009, 9, 30, 0, 0)}
# {'programming_language': 2,
#  'publish_date': datetime.datetime(2009, 9, 30, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 3, 27, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 8, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 8, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 8, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 8, 28, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 8, 28, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 8, 28, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 8, 28, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 9, 17, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 9, 17, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 7, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 9, 0, 0)}
# {'programming_language': 2,
#  'publish_date': datetime.datetime(2009, 10, 20, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 11, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 20, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 8, 27, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 8, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 8, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 8, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 8, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 8, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 8, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 8, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 9, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 9, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 9, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 9, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 9, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 9, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 12, 0, 0)}
# {'programming_language': 1,
# ...
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 6, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 1, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 1, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 1, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 1, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 1, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 2, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 2, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 2, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 2, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 3, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 3, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 3, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 3, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 4, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 4, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 4, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 4, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 4, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 5, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 5, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 5, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 5, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 6, 6, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 22, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 22, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 22, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 22, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 22, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 23, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 23, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 6, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 6, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 6, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 6, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 6, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 6, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 6, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 6, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 6, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 6, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 6, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 6, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 7, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 9, 7, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 7, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 7, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 7, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 7, 0, 0)}
# {'programming_language': 2, 'publish_date': datetime.datetime(2009, 5, 6, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 23, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 23, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 22, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 22, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 7, 21, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 7, 20, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 7, 20, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 7, 20, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 7, 20, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 7, 21, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 7, 21, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 7, 21, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 7, 21, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 7, 21, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 7, 20, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 7, 21, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 3, 8, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 3, 8, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 3, 8, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 4, 8, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 8, 18, 0, 0)}
# {'programming_language': 2,
#  'publish_date': datetime.datetime(2009, 9, 14, 0, 0)}
# {'programming_language': 2, 'publish_date': datetime.datetime(2009, 4, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 4, 6, 0, 0)}
# {'programming_language': 2, 'publish_date': datetime.datetime(2009, 4, 6, 0, 0)}
# {'programming_language': 2, 'publish_date': datetime.datetime(2009, 4, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 4, 6, 0, 0)}
# {'programming_language': 2, 'publish_date': datetime.datetime(2009, 4, 6, 0, 0)}
# {'programming_language': 2, 'publish_date': datetime.datetime(2009, 4, 6, 0, 0)}
# {'programming_language': 2, 'publish_date': datetime.datetime(2009, 4, 6, 0, 0)}
# {'programming_language': 2, 'publish_date': datetime.datetime(2009, 4, 6, 0, 0)}
# {'programming_language': 2, 'publish_date': datetime.datetime(2009, 5, 6, 0, 0)}
# {'programming_language': 2, 'publish_date': datetime.datetime(2009, 5, 6, 0, 0)}
# {'programming_language': 2, 'publish_date': datetime.datetime(2009, 5, 6, 0, 0)}
# {'programming_language': 2, 'publish_date': datetime.datetime(2009, 5, 6, 0, 0)}
# {'programming_language': 2, 'publish_date': datetime.datetime(2009, 6, 6, 0, 0)}
# {'programming_language': 2, 'publish_date': datetime.datetime(2009, 6, 6, 0, 0)}
# {'programming_language': 2,
#  'publish_date': datetime.datetime(2009, 11, 6, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 7, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 8, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 4, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 4, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 4, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 4, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 4, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 5, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 5, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 6, 9, 0, 0)}
# {'programming_language': 1, 'publish_date': datetime.datetime(2009, 6, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 1, 10, 0, 0)}
# {'programming_language': 2,
#  'publish_date': datetime.datetime(2009, 1, 10, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 2, 10, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 2, 10, 0, 0)}
# {'programming_language': 2,
#  'publish_date': datetime.datetime(2009, 2, 10, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 9, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 9, 28, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 9, 28, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 9, 29, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 9, 29, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 9, 29, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 1, 10, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 1, 10, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 2, 10, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 2, 10, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 2, 10, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 2, 10, 0, 0)}
# {'programming_language': 2,
#  'publish_date': datetime.datetime(2009, 10, 7, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 29, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 29, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 29, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 30, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 6, 22, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 8, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 8, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 9, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 7, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 7, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 7, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 7, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 7, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 7, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 10, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 11, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 12, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 12, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 12, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 12, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 12, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 12, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 12, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 12, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 12, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 12, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 12, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 12, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 12, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 12, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 12, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 12, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 12, 12, 0, 0)}
# {'programming_language': 1,
#  'publish_date': datetime.datetime(2009, 12, 12, 0, 0)}

# %%
db.challenge.count_documents(
    # query expression
    {
        'publish_date':{'$gte':datetime(2009,1,1),'$lte':datetime(2010,1,1)}
    }
)
# Out:
# 888

# %% [markdown]
# ### Q4.
#
# How many challenges have been written by author `AI563576` in either `programming_language` `1` or `3` ?

# %%
cur = db.challenge.find(
    # query expression
    {
        'author.id':'AI563576',
        'programming_language':{'$in':[1,3]}
    },
    # projection
    {
        'author.id':1,
        'programming_language':1,
        '_id':0
    })
# Print docs
for doc in cur :
    pp.pprint(doc)
# Out:
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 3, 'author': {'id': 'AI563576'}}
# {'programming_language': 3, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}
# {'programming_language': 1, 'author': {'id': 'AI563576'}}

# %%
db.challenge.count_documents(
    # query expression
    {
        'author.id':'AI563576',
        'programming_language':{'$in':[1,3]}
    }
)
# Out:
# 41

# %% [markdown]
# ### Q5.
#
# How many documents are there where the challenges have been created by a female author and where the author belong to either the 'AOI100013' organisation or the 'AOI100013' organisation?

# %%
pp.pprint(
    db.challenge.find_one()
)
# Out:
# {'_id': ObjectId('60dab9f75945974466d8d64d'),
#  'challenge_id': 'CI23478',
#  'programming_language': 2,
#  'total_submissions': 37,
#  'publish_date': datetime.datetime(2006, 6, 5, 0, 0),
#  'author': {'id': 'AI563576', 'gender': 'M', 'org_id': 'AOI100001'},
#  'users': [32876, 88820, 97150, 97359]}

# %%
cur = db.challenge.find(
    # query expression
    {
        'author.gender':'F',
        'author.org_id':{'$in':['AOI100013','AOI1000013']}
    },
    # projection
    {
        'author.gender':1,
        'author.org_id':1,
        '_id':0
    })
# Print docs
for doc in cur :
    pp.pprint(doc)
# Out:
# {'author': {'gender': 'F', 'org_id': 'AOI100013'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100013'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100013'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100013'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100013'}}

# %% [markdown]
# # Both the org given is same - finding another org which has 'F'

# %%
cur = db.challenge.find(
    # query expression
    {
        'author.gender':'F'
    },
    # projection
    {
        'author.gender':1,
        'author.org_id':1,
        '_id':0
    })
# Print docs
for doc in cur :
    pp.pprint(doc)
# Out:
# {'author': {'gender': 'F', 'org_id': 'AOI100007'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100008'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100012'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100013'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100024'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100026'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100027'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100035'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100001'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100011'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100007'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100052'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100053'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100060'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100062'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100063'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100064'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100072'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100002'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100077'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100079'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100001'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100102'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100134'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100140'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100145'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100151'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100154'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100158'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100190'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100191'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100193'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100197'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100206'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100204'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100001'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100088'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100250'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100212'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100275'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100222'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100141'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100308'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100311'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100202'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100239'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100001'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100026'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100343'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100243'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100309'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100386'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100233'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100130'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100411'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100150'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100451'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100468'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100472'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100030'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100130'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100001'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100130'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100486'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100052'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100491'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100386'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100278'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100517'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100525'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100145'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100001'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100505'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100001'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100556'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100559'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100505'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100568'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100154'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100154'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100145'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100145'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100619'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100228'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100199'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100647'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100213'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100701'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100737'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100761'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100145'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100403'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100137'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100164'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100829'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100716'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100911'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100917'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100928'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100047'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100945'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100228'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100962'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100968'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100362'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100217'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100987'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100999'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100397'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100998'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101002'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101010'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101012'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101020'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101029'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100565'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100868'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100079'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100326'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101114'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100063'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100227'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100204'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100586'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101123'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100072'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101158'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100137'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100811'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100164'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100013'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100013'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100013'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101122'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100895'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100709'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101379'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100154'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100154'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100165'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100165'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100222'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100129'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100122'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101381'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100655'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100384'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100329'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101391'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101396'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100411'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100584'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101397'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100411'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101400'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101401'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101403'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101405'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101407'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101416'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101420'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101421'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100026'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101424'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101425'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101428'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101429'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101432'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101434'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101433'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101429'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101435'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100308'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100113'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101437'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101369'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100026'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101441'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101444'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100026'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100550'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100253'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101445'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101376'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100912'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101447'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101447'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100194'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100173'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100228'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101376'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101454'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100602'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101456'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100691'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101458'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101322'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100164'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101458'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100032'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101466'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101473'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100678'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101480'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100593'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101481'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101483'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101483'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101472'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100593'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100011'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101490'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100350'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101490'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101491'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100981'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100678'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101503'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101507'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101508'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101270'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101514'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100230'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101515'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100173'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100212'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100591'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100574'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100957'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100256'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100212'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100429'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101532'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100901'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101543'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101545'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100574'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101547'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100075'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100109'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100947'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101561'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100230'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101563'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100063'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100047'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101569'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101569'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101570'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100994'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101570'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101121'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100001'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100202'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101573'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100308'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101577'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100590'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101241'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100239'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100063'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100054'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100019'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101597'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100008'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101424'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101036'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100749'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101244'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100574'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101611'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101612'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101613'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100001'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100001'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100001'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100026'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101036'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101619'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100003'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101620'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101631'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100166'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101635'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101638'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100022'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101644'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100165'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101647'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101654'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101655'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101661'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100026'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101677'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100001'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100228'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101044'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101674'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100716'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101689'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100153'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101692'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101110'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100154'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100120'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101696'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101253'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101253'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101701'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100018'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100144'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101712'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100032'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101715'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101529'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101718'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100022'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100001'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100161'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100163'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100165'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100167'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100022'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100093'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100189'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100195'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100199'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100199'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100230'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100022'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100141'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100193'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100291'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100228'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100297'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100300'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100305'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100138'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100230'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100141'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100141'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100161'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100228'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100022'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100158'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100155'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100120'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100280'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100287'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100164'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100228'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100158'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100340'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100049'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100377'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100395'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100130'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100129'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100420'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100424'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100376'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100465'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100181'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100001'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100204'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100130'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100130'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100130'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100130'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100499'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100350'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100353'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100362'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100217'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100133'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100374'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100193'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100399'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100130'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100376'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100431'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100096'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100390'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100454'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100460'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100130'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100327'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100154'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100001'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100337'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100133'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100080'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100072'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100130'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100386'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100417'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100425'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100067'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100032'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100454'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100470'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100192'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100130'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100130'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100525'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100528'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100536'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100541'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100453'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100506'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100510'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100053'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100526'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100544'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100560'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100141'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100581'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100597'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100154'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100185'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100222'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100509'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100517'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100524'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100013'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100545'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100550'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100553'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100573'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100580'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100593'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100154'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100085'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100602'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100615'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100085'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100001'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100696'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100698'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100590'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100716'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100611'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100732'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100740'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100757'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100318'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100318'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100690'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100230'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100757'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100184'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100080'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100154'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100555'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100563'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100154'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100154'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100154'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100228'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100667'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100113'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100145'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100611'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100080'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100810'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100835'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100839'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100849'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100886'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100001'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100913'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100916'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100927'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100215'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100938'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100735'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100141'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100800'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100138'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100026'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100130'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101012'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101029'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101049'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101055'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101062'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100900'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100913'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100918'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100919'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100925'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100932'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100936'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100429'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100947'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100001'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100979'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100141'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100011'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100130'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100411'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101032'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101036'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100204'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100138'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100800'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100800'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100853'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100261'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100701'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100900'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100908'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100397'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100073'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100635'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100137'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100716'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100096'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100278'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100062'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100995'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100397'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101001'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100998'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100001'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101046'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100691'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100145'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101088'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101110'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100735'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100227'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100294'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100678'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100212'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100731'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100709'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100386'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100840'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100025'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100052'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100212'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100417'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100581'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100901'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100202'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101248'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100210'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100192'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101044'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101066'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100358'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100735'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100483'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100227'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101121'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101161'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100080'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101186'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100912'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100089'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101241'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100213'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101241'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101104'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100417'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100173'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101102'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100735'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100684'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100174'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100678'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100054'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101153'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100430'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100655'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100052'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101193'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101198'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101224'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100574'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100369'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100635'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100174'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101253'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101253'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101253'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101253'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101253'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101253'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101253'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101253'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101253'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101253'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101253'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101253'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101253'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101253'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101253'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101253'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101253'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100201'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100936'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100701'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100479'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101274'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100708'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101255'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101289'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101199'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100011'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101299'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101300'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100411'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101322'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101278'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101257'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100529'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101271'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100235'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100141'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101294'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100063'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101297'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100001'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100137'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100890'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100987'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101322'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101324'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100390'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101337'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100204'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101337'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101344'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100093'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100120'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101356'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101369'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101372'}}
# {'author': {'gender': 'F', 'org_id': 'AOI101373'}}

# %%
cur = db.challenge.find(
    # query expression
    {
        'author.gender':'F',
        'author.org_id':{'$in':['AOI100013','AOI100007']}
    },
    # projection
    {
        'author.gender':1,
        'author.org_id':1,
        '_id':0
    })
# Print docs
for doc in cur :
    pp.pprint(doc)
# Out:
# {'author': {'gender': 'F', 'org_id': 'AOI100007'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100013'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100007'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100013'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100013'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100013'}}
# {'author': {'gender': 'F', 'org_id': 'AOI100013'}}

# %% [markdown]
# ### Q5.(updated with org )
#
# How many documents are there where the challenges have been created by a female author and where the author belong to either the 'AOI100013' organisation or the 'AOI100007' organisation?

# %%
db.challenge.count_documents(
    # query expression
    {
        'author.gender':'F',
        'author.org_id':{'$in':['AOI100013','AOI100007']}
    }
)
# Out:
# 7

# %% [markdown]
# ### Q6.
#
# Find the top 5 challenges where either the challenge has been attempted by exactly 100 `users` or where the `total_submissions` is between 100 and 200, both inclusive?

# %%
pp.pprint(
    db.challenge.find_one()
)
# Out:
# {'_id': ObjectId('60dab9f75945974466d8d64d'),
#  'challenge_id': 'CI23478',
#  'programming_language': 2,
#  'total_submissions': 37,
#  'publish_date': datetime.datetime(2006, 6, 5, 0, 0),
#  'author': {'id': 'AI563576', 'gender': 'M', 'org_id': 'AOI100001'},
#  'users': [32876, 88820, 97150, 97359]}

# %%
# Get docs with Users = 100
cur = db.challenge.find(
    # query expression
    {
        'users':{'$size' : 100
                   }
    },
    # projection
    {
        'challenge_id':1,
        'users':1,
        '_id':0
    })
# Print docs
for doc in cur :
    pp.pprint(doc)
# Out:
# {'challenge_id': 'CI23792',
#  'users': [23484,
#            24298,
#            24655,
#            25104,
#            28031,
#            28855,
#            29312,
#            30184,
#            33431,
#            33496,
#            35603,
#            36610,
#            37716,
#            37865,
#            40559,
#            40935,
#            41077,
#            41482,
#            41774,
#            41846,
#            44253,
#            45015,
#            45797,
#            47042,
#            47559,
#            50877,
#            51729,
#            51845,
#            52284,
#            54212,
#            55472,
#            55858,
#            57443,
#            60405,
#            60957,
#            60968,
#            61988,
#            62049,
#            63008,
#            64075,
#            65561,
#            65684,
#            66671,
#            68069,
#            68131,
#            70417,
#            70942,
#            71201,
#            72559,
#            73752,
#            73825,
#            74136,
#            75408,
#            77133,
#            78274,
#            78986,
#            80229,
#            80527,
#            81220,
#            81718,
#            83302,
#            83581,
#            84901,
#            86569,
#            86755,
#            87392,
#            89234,
#            89641,
#            89822,
#            91969,
#            92397,
#            93842,
#            96082,
#            96153,
#            96220,
#            96791,
#            96976,
#            97058,
#            98091,
#            98592,
#            101010,
#            101013,
#            101242,
#            102087,
#            102088,
#            102127,
#            102480,
#            104203,
#            104722,
#            105359,
#            105688,
#            105948,
#            108526,
#            109634,
#            109978,
#            111173,
#            111573,
#            112726,
#            113344,
#            113470]}
# {'challenge_id': 'CI24175',
#  'users': [19339,
#            20747,
#            22525,
#            27347,
#            40084,
#            40114,
#            42177,
#            44854,
#            47625,
#            48631,
#            49112,
#            49423,
#            50055,
#            50056,
#            53535,
#            54876,
#            55056,
#            56315,
#            57187,
#            58126,
#            58803,
#            61074,
#            61197,
#            61281,
#            62684,
#            62685,
#            63396,
#            64443,
#            67045,
#            67215,
#            68052,
#            68922,
#            69869,
#            70199,
#            71906,
#            73665,
#            73954,
#            74176,
#            75274,
#            75475,
#            75819,
#            75820,
#            76184,
#            76211,
#            76297,
#            76479,
#            77084,
#            77085,
#            77200,
#            79851,
#            80475,
#            81573,
#            81927,
#            82629,
#            82725,
#            85949,
#            86023,
#            87884,
#            88434,
#            88800,
#            89586,
#            92602,
#            93751,
#            95299,
#            95410,
#            95484,
#            95489,
#            97319,
#            98257,
#            98451,
#            100125,
#            101350,
#            102595,
#            103111,
#            104076,
#            104280,
#            104699,
#            104703,
#            105081,
#            105082,
#            105499,
#            106211,
#            106482,
#            107196,
#            107200,
#            107455,
#            107489,
#            108394,
#            109484,
#            109593,
#            109988,
#            110224,
#            110581,
#            111149,
#            111792,
#            113495,
#            113699,
#            113701,
#            113706,
#            113709]}
# {'challenge_id': 'CI25598',
#  'users': [20883,
#            28361,
#            34057,
#            35757,
#            35981,
#            44701,
#            45240,
#            45786,
#            46082,
#            46216,
#            46300,
#            46499,
#            47271,
#            47661,
#            48059,
#            52945,
#            53241,
#            54024,
#            54576,
#            56383,
#            57343,
#            58145,
#            58387,
#            58455,
#            59195,
#            59286,
#            59453,
#            60526,
#            61011,
#            63361,
#            64151,
#            65289,
#            65633,
#            66352,
#            66407,
#            66836,
#            67597,
#            68422,
#            68959,
#            68977,
#            69033,
#            69056,
#            69072,
#            70495,
#            71621,
#            72337,
#            72354,
#            72743,
#            74125,
#            76052,
#            80089,
#            80102,
#            80218,
#            82263,
#            82600,
#            83308,
#            84149,
#            84240,
#            85489,
#            86120,
#            87765,
#            88253,
#            88323,
#            89205,
#            89495,
#            89535,
#            95473,
#            95770,
#            97051,
#            97601,
#            99398,
#            99578,
#            99827,
#            99834,
#            100044,
#            100046,
#            100328,
#            100329,
#            100333,
#            100452,
#            101349,
#            101568,
#            104556,
#            105513,
#            106851,
#            107493,
#            107601,
#            107698,
#            107897,
#            108248,
#            108281,
#            108486,
#            108693,
#            109506,
#            109610,
#            109614,
#            109616,
#            110451,
#            111680,
#            113215]}

# %% [markdown]
# **Count how  many - where either the challenge has been attempted by exactly 100 users**

# %%
cur.count()
# Out:
# <ipython-input-24-718516a61838>:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   cur.count()
# 3

# %%
find = {'users':{'$size' : 100}}
db.challenge.count_documents(find)
# Out:
# 3

# %%
# Find docs with total submission is between 100 and 200, both  inclusive

# %%
cur = db.challenge.find(
    # query expression
    {
        'total_submissions':{
                '$gte':100,
                '$lte':200
    }    },
    # projection
    {
        'total_submissions':1,
        '_id':0
    })
# Print docs
for doc in cur :
    pp.pprint(doc)
# Out:
# {'total_submissions': 137}
# {'total_submissions': 173}
# {'total_submissions': 195}
# {'total_submissions': 112}
# {'total_submissions': 104}
# {'total_submissions': 103}
# {'total_submissions': 193}
# {'total_submissions': 153}
# {'total_submissions': 169}
# {'total_submissions': 164}
# {'total_submissions': 110}
# {'total_submissions': 171}
# {'total_submissions': 135}
# {'total_submissions': 193}
# {'total_submissions': 104}
# {'total_submissions': 114}
# {'total_submissions': 180}
# {'total_submissions': 105}
# {'total_submissions': 138}
# {'total_submissions': 165}
# {'total_submissions': 112}
# {'total_submissions': 130}
# {'total_submissions': 114}
# {'total_submissions': 136}
# {'total_submissions': 108}
# {'total_submissions': 174}
# {'total_submissions': 102}
# {'total_submissions': 188}
# {'total_submissions': 107}
# {'total_submissions': 157}
# {'total_submissions': 185}
# {'total_submissions': 122}
# {'total_submissions': 134}
# {'total_submissions': 104}
# {'total_submissions': 164}
# {'total_submissions': 126}
# {'total_submissions': 105}
# {'total_submissions': 161}
# {'total_submissions': 148}
# {'total_submissions': 130}
# {'total_submissions': 129}
# {'total_submissions': 199}
# {'total_submissions': 116}
# {'total_submissions': 129}
# {'total_submissions': 103}
# {'total_submissions': 153}
# {'total_submissions': 170}
# {'total_submissions': 113}
# {'total_submissions': 129}
# {'total_submissions': 166}
# {'total_submissions': 151}
# {'total_submissions': 173}
# {'total_submissions': 156}
# {'total_submissions': 133}
# {'total_submissions': 145}
# {'total_submissions': 200}
# {'total_submissions': 107}
# {'total_submissions': 120}
# {'total_submissions': 120}
# {'total_submissions': 161}
# {'total_submissions': 171}
# {'total_submissions': 105}
# {'total_submissions': 185}
# {'total_submissions': 159}
# {'total_submissions': 130}
# {'total_submissions': 101}
# {'total_submissions': 125}
# {'total_submissions': 122}
# {'total_submissions': 155}
# {'total_submissions': 148}
# {'total_submissions': 138}
# {'total_submissions': 197}
# {'total_submissions': 109}
# {'total_submissions': 175}
# {'total_submissions': 133}
# {'total_submissions': 179}
# {'total_submissions': 165}
# {'total_submissions': 120}
# {'total_submissions': 199}
# {'total_submissions': 170}
# {'total_submissions': 170}
# {'total_submissions': 130}
# {'total_submissions': 111}
# {'total_submissions': 131}
# {'total_submissions': 133}
# {'total_submissions': 154}
# {'total_submissions': 120}
# {'total_submissions': 112}
# {'total_submissions': 151}
# {'total_submissions': 146}
# {'total_submissions': 100}
# {'total_submissions': 160}
# {'total_submissions': 121}
# {'total_submissions': 118}
# {'total_submissions': 135}
# {'total_submissions': 138}
# {'total_submissions': 192}
# {'total_submissions': 178}
# {'total_submissions': 179}
# {'total_submissions': 173}
# {'total_submissions': 162}
# {'total_submissions': 146}
# {'total_submissions': 114}
# {'total_submissions': 146}
# {'total_submissions': 194}
# {'total_submissions': 121}
# {'total_submissions': 181}
# {'total_submissions': 185}
# {'total_submissions': 129}
# {'total_submissions': 174}
# {'total_submissions': 174}
# {'total_submissions': 186}
# {'total_submissions': 120}
# {'total_submissions': 170}
# {'total_submissions': 108}
# {'total_submissions': 173}
# {'total_submissions': 117}
# {'total_submissions': 150}
# {'total_submissions': 120}
# {'total_submissions': 113}
# {'total_submissions': 108}
# {'total_submissions': 126}
# {'total_submissions': 106}
# {'total_submissions': 158}
# {'total_submissions': 143}
# {'total_submissions': 173}
# {'total_submissions': 149}
# {'total_submissions': 193}
# {'total_submissions': 166}
# {'total_submissions': 162}
# {'total_submissions': 147}
# {'total_submissions': 192}
# {'total_submissions': 100}
# {'total_submissions': 116}
# {'total_submissions': 119}
# {'total_submissions': 183}
# {'total_submissions': 198}
# {'total_submissions': 133}
# {'total_submissions': 164}
# {'total_submissions': 180}
# {'total_submissions': 157}
# {'total_submissions': 178}
# {'total_submissions': 129}
# {'total_submissions': 161}
# {'total_submissions': 111}
# {'total_submissions': 143}
# {'total_submissions': 130}
# {'total_submissions': 157}
# {'total_submissions': 196}
# {'total_submissions': 183}
# {'total_submissions': 168}
# {'total_submissions': 110}
# {'total_submissions': 124}
# {'total_submissions': 164}
# {'total_submissions': 136}
# {'total_submissions': 159}
# {'total_submissions': 153}
# {'total_submissions': 110}
# {'total_submissions': 125}
# {'total_submissions': 134}
# {'total_submissions': 152}
# {'total_submissions': 123}
# {'total_submissions': 178}
# {'total_submissions': 181}
# {'total_submissions': 106}
# {'total_submissions': 130}
# {'total_submissions': 120}
# {'total_submissions': 123}
# {'total_submissions': 137}
# {'total_submissions': 175}
# {'total_submissions': 198}
# {'total_submissions': 133}
# {'total_submissions': 191}
# {'total_submissions': 102}
# {'total_submissions': 171}
# {'total_submissions': 138}
# {'total_submissions': 131}
# {'total_submissions': 102}
# {'total_submissions': 182}
# {'total_submissions': 171}
# {'total_submissions': 131}
# {'total_submissions': 107}
# {'total_submissions': 185}
# {'total_submissions': 116}
# {'total_submissions': 147}
# {'total_submissions': 132}
# {'total_submissions': 125}
# {'total_submissions': 157}
# {'total_submissions': 105}
# {'total_submissions': 183}
# {'total_submissions': 180}
# {'total_submissions': 134}
# {'total_submissions': 138}
# {'total_submissions': 106}
# {'total_submissions': 159}
# {'total_submissions': 139}
# {'total_submissions': 121}
# {'total_submissions': 124}
# {'total_submissions': 188}
# {'total_submissions': 198}
# {'total_submissions': 119}
# {'total_submissions': 112}
# {'total_submissions': 102}
# {'total_submissions': 106}
# {'total_submissions': 141}
# {'total_submissions': 114}
# {'total_submissions': 118}
# {'total_submissions': 126}
# {'total_submissions': 190}
# {'total_submissions': 119}
# {'total_submissions': 129}
# {'total_submissions': 116}
# {'total_submissions': 170}
# {'total_submissions': 119}
# {'total_submissions': 135}
# {'total_submissions': 151}
# {'total_submissions': 114}
# {'total_submissions': 111}
# {'total_submissions': 180}
# {'total_submissions': 103}
# {'total_submissions': 114}
# {'total_submissions': 185}
# {'total_submissions': 193}
# {'total_submissions': 112}
# {'total_submissions': 101}
# {'total_submissions': 141}
# {'total_submissions': 148}
# {'total_submissions': 161}
# {'total_submissions': 134}
# {'total_submissions': 102}
# {'total_submissions': 160}
# {'total_submissions': 122}
# {'total_submissions': 133}
# {'total_submissions': 144}
# {'total_submissions': 157}
# {'total_submissions': 111}
# {'total_submissions': 124}
# {'total_submissions': 180}
# {'total_submissions': 189}
# {'total_submissions': 122}
# {'total_submissions': 183}
# {'total_submissions': 158}
# {'total_submissions': 165}
# {'total_submissions': 127}
# {'total_submissions': 101}
# {'total_submissions': 132}
# {'total_submissions': 177}
# {'total_submissions': 169}
# {'total_submissions': 192}
# {'total_submissions': 198}
# {'total_submissions': 148}
# {'total_submissions': 144}
# {'total_submissions': 132}
# {'total_submissions': 170}
# {'total_submissions': 126}
# {'total_submissions': 166}
# {'total_submissions': 129}
# {'total_submissions': 141}
# {'total_submissions': 141}
# {'total_submissions': 118}
# {'total_submissions': 198}
# {'total_submissions': 183}
# {'total_submissions': 175}
# {'total_submissions': 191}
# {'total_submissions': 100}
# {'total_submissions': 177}
# {'total_submissions': 134}
# {'total_submissions': 169}
# {'total_submissions': 144}
# {'total_submissions': 103}
# {'total_submissions': 130}
# {'total_submissions': 165}
# {'total_submissions': 120}
# {'total_submissions': 169}
# {'total_submissions': 164}
# {'total_submissions': 130}
# {'total_submissions': 114}
# {'total_submissions': 126}
# {'total_submissions': 132}
# {'total_submissions': 165}
# {'total_submissions': 200}
# {'total_submissions': 111}
# {'total_submissions': 187}
# {'total_submissions': 152}
# {'total_submissions': 178}
# {'total_submissions': 185}
# {'total_submissions': 148}
# {'total_submissions': 192}
# {'total_submissions': 120}
# {'total_submissions': 127}
# {'total_submissions': 104}
# {'total_submissions': 189}
# {'total_submissions': 122}
# {'total_submissions': 103}
# {'total_submissions': 185}
# {'total_submissions': 153}
# {'total_submissions': 138}
# {'total_submissions': 153}
# {'total_submissions': 108}
# {'total_submissions': 192}
# {'total_submissions': 159}
# {'total_submissions': 135}
# {'total_submissions': 147}
# {'total_submissions': 175}
# {'total_submissions': 155}
# {'total_submissions': 185}
# {'total_submissions': 175}
# {'total_submissions': 172}
# {'total_submissions': 179}
# {'total_submissions': 102}
# {'total_submissions': 153}
# {'total_submissions': 105}
# {'total_submissions': 116}
# {'total_submissions': 184}
# {'total_submissions': 100}
# {'total_submissions': 188}
# {'total_submissions': 134}
# {'total_submissions': 159}
# {'total_submissions': 146}
# {'total_submissions': 132}
# {'total_submissions': 130}
# {'total_submissions': 112}
# {'total_submissions': 117}
# {'total_submissions': 101}
# {'total_submissions': 174}
# {'total_submissions': 121}
# {'total_submissions': 136}
# {'total_submissions': 113}
# {'total_submissions': 171}
# {'total_submissions': 183}
# {'total_submissions': 156}
# {'total_submissions': 130}
# {'total_submissions': 112}
# {'total_submissions': 104}
# {'total_submissions': 110}
# {'total_submissions': 178}
# {'total_submissions': 143}
# {'total_submissions': 133}
# {'total_submissions': 176}
# {'total_submissions': 124}
# {'total_submissions': 108}
# {'total_submissions': 134}
# {'total_submissions': 138}
# {'total_submissions': 110}
# {'total_submissions': 100}
# {'total_submissions': 168}
# {'total_submissions': 170}
# {'total_submissions': 197}
# {'total_submissions': 137}
# {'total_submissions': 159}
# {'total_submissions': 155}
# {'total_submissions': 101}
# {'total_submissions': 127}
# {'total_submissions': 119}
# {'total_submissions': 101}
# {'total_submissions': 124}
# {'total_submissions': 115}
# {'total_submissions': 146}
# {'total_submissions': 187}
# {'total_submissions': 100}
# {'total_submissions': 133}
# {'total_submissions': 118}
# {'total_submissions': 166}
# {'total_submissions': 107}
# {'total_submissions': 112}
# {'total_submissions': 118}
# {'total_submissions': 130}
# {'total_submissions': 110}
# {'total_submissions': 101}
# {'total_submissions': 128}
# {'total_submissions': 190}
# {'total_submissions': 186}
# {'total_submissions': 113}
# {'total_submissions': 116}
# {'total_submissions': 165}
# {'total_submissions': 112}
# {'total_submissions': 115}
# {'total_submissions': 164}
# {'total_submissions': 142}
# {'total_submissions': 134}
# {'total_submissions': 149}
# {'total_submissions': 102}
# {'total_submissions': 193}
# {'total_submissions': 106}
# {'total_submissions': 134}
# {'total_submissions': 120}
# {'total_submissions': 133}
# {'total_submissions': 177}
# {'total_submissions': 143}
# {'total_submissions': 140}
# {'total_submissions': 168}
# {'total_submissions': 145}
# {'total_submissions': 147}
# {'total_submissions': 189}
# {'total_submissions': 152}
# {'total_submissions': 131}
# {'total_submissions': 192}
# {'total_submissions': 181}
# {'total_submissions': 130}
# {'total_submissions': 157}
# {'total_submissions': 112}
# {'total_submissions': 130}
# {'total_submissions': 186}
# {'total_submissions': 119}
# {'total_submissions': 174}
# {'total_submissions': 191}
# {'total_submissions': 132}
# {'total_submissions': 186}
# {'total_submissions': 106}
# {'total_submissions': 192}
# {'total_submissions': 124}
# {'total_submissions': 105}
# {'total_submissions': 164}
# {'total_submissions': 129}
# {'total_submissions': 107}
# {'total_submissions': 187}
# {'total_submissions': 148}
# {'total_submissions': 180}
# {'total_submissions': 190}
# {'total_submissions': 139}
# {'total_submissions': 144}
# {'total_submissions': 114}
# {'total_submissions': 137}
# {'total_submissions': 158}
# {'total_submissions': 193}
# {'total_submissions': 150}
# {'total_submissions': 116}
# {'total_submissions': 133}
# {'total_submissions': 117}
# {'total_submissions': 137}
# {'total_submissions': 115}
# {'total_submissions': 166}
# {'total_submissions': 174}
# {'total_submissions': 192}
# {'total_submissions': 160}
# {'total_submissions': 183}
# {'total_submissions': 108}
# {'total_submissions': 126}
# {'total_submissions': 122}
# {'total_submissions': 131}
# {'total_submissions': 114}
# {'total_submissions': 189}
# {'total_submissions': 150}
# {'total_submissions': 135}
# {'total_submissions': 121}
# {'total_submissions': 123}
# {'total_submissions': 114}
# {'total_submissions': 153}
# {'total_submissions': 156}
# {'total_submissions': 158}
# {'total_submissions': 200}
# {'total_submissions': 100}
# {'total_submissions': 130}
# {'total_submissions': 106}
# {'total_submissions': 185}
# {'total_submissions': 102}
# {'total_submissions': 104}
# {'total_submissions': 132}
# {'total_submissions': 166}
# {'total_submissions': 116}
# {'total_submissions': 136}
# {'total_submissions': 114}
# {'total_submissions': 146}
# {'total_submissions': 130}
# {'total_submissions': 144}
# {'total_submissions': 129}
# {'total_submissions': 121}
# {'total_submissions': 139}
# {'total_submissions': 141}
# {'total_submissions': 105}
# {'total_submissions': 117}
# {'total_submissions': 126}
# {'total_submissions': 100}
# {'total_submissions': 108}
# {'total_submissions': 114}
# {'total_submissions': 134}
# {'total_submissions': 155}
# {'total_submissions': 120}
# {'total_submissions': 161}
# {'total_submissions': 105}
# {'total_submissions': 120}
# {'total_submissions': 149}
# {'total_submissions': 168}
# {'total_submissions': 156}
# {'total_submissions': 148}
# {'total_submissions': 140}
# {'total_submissions': 180}
# {'total_submissions': 101}
# {'total_submissions': 130}
# {'total_submissions': 102}
# {'total_submissions': 133}
# {'total_submissions': 196}
# {'total_submissions': 146}
# {'total_submissions': 165}
# {'total_submissions': 105}
# {'total_submissions': 140}
# {'total_submissions': 102}
# {'total_submissions': 145}
# {'total_submissions': 169}
# {'total_submissions': 135}
# {'total_submissions': 120}
# {'total_submissions': 164}
# {'total_submissions': 104}
# {'total_submissions': 197}
# {'total_submissions': 138}
# {'total_submissions': 109}
# {'total_submissions': 150}
# {'total_submissions': 102}
# {'total_submissions': 165}
# {'total_submissions': 180}
# {'total_submissions': 103}
# {'total_submissions': 130}
# {'total_submissions': 118}
# {'total_submissions': 145}
# {'total_submissions': 115}
# {'total_submissions': 198}
# {'total_submissions': 181}
# {'total_submissions': 129}
# {'total_submissions': 200}
# {'total_submissions': 151}
# {'total_submissions': 120}
# {'total_submissions': 110}
# {'total_submissions': 102}
# {'total_submissions': 162}
# {'total_submissions': 146}
# {'total_submissions': 106}
# {'total_submissions': 123}
# {'total_submissions': 149}
# {'total_submissions': 114}
# {'total_submissions': 181}
# {'total_submissions': 169}
# {'total_submissions': 100}
# {'total_submissions': 169}
# {'total_submissions': 112}
# {'total_submissions': 121}
# {'total_submissions': 195}
# {'total_submissions': 184}
# {'total_submissions': 174}
# {'total_submissions': 154}
# {'total_submissions': 134}
# {'total_submissions': 103}
# {'total_submissions': 197}
# {'total_submissions': 149}
# {'total_submissions': 131}
# {'total_submissions': 117}
# {'total_submissions': 135}
# {'total_submissions': 165}
# {'total_submissions': 107}
# {'total_submissions': 108}
# {'total_submissions': 115}
# {'total_submissions': 104}
# {'total_submissions': 114}
# {'total_submissions': 109}
# {'total_submissions': 140}
# {'total_submissions': 130}
# {'total_submissions': 136}
# {'total_submissions': 118}
# {'total_submissions': 186}
# {'total_submissions': 160}
# {'total_submissions': 100}
# {'total_submissions': 166}
# {'total_submissions': 174}
# {'total_submissions': 136}
# {'total_submissions': 136}
# {'total_submissions': 158}
# {'total_submissions': 114}
# {'total_submissions': 183}
# {'total_submissions': 123}
# {'total_submissions': 105}
# {'total_submissions': 161}
# {'total_submissions': 134}
# {'total_submissions': 134}
# {'total_submissions': 124}
# {'total_submissions': 133}
# {'total_submissions': 137}
# {'total_submissions': 164}
# {'total_submissions': 149}
# {'total_submissions': 107}
# {'total_submissions': 197}
# {'total_submissions': 133}
# {'total_submissions': 128}
# {'total_submissions': 109}
# {'total_submissions': 166}
# {'total_submissions': 108}
# {'total_submissions': 136}
# {'total_submissions': 151}
# {'total_submissions': 133}
# {'total_submissions': 141}
# {'total_submissions': 112}
# {'total_submissions': 166}
# {'total_submissions': 120}
# {'total_submissions': 106}
# {'total_submissions': 173}
# {'total_submissions': 116}
# {'total_submissions': 180}
# {'total_submissions': 132}
# {'total_submissions': 134}
# {'total_submissions': 187}
# {'total_submissions': 122}
# {'total_submissions': 185}
# {'total_submissions': 117}
# {'total_submissions': 146}
# {'total_submissions': 136}
# {'total_submissions': 141}
# {'total_submissions': 174}
# {'total_submissions': 162}
# {'total_submissions': 145}
# {'total_submissions': 135}
# {'total_submissions': 129}
# {'total_submissions': 117}
# {'total_submissions': 100}
# {'total_submissions': 193}
# {'total_submissions': 104}
# {'total_submissions': 180}
# {'total_submissions': 194}
# {'total_submissions': 105}
# {'total_submissions': 144}
# {'total_submissions': 135}
# {'total_submissions': 184}
# {'total_submissions': 182}
# {'total_submissions': 179}
# {'total_submissions': 121}
# {'total_submissions': 161}
# {'total_submissions': 173}
# {'total_submissions': 102}
# {'total_submissions': 164}
# {'total_submissions': 186}
# {'total_submissions': 141}
# {'total_submissions': 189}
# {'total_submissions': 157}
# {'total_submissions': 152}
# {'total_submissions': 106}
# {'total_submissions': 153}
# {'total_submissions': 170}
# {'total_submissions': 184}
# {'total_submissions': 121}
# {'total_submissions': 119}
# {'total_submissions': 121}
# {'total_submissions': 134}
# {'total_submissions': 104}
# {'total_submissions': 183}
# {'total_submissions': 127}
# {'total_submissions': 147}
# {'total_submissions': 141}
# {'total_submissions': 114}
# {'total_submissions': 139}
# {'total_submissions': 154}
# {'total_submissions': 134}
# {'total_submissions': 159}
# {'total_submissions': 155}
# {'total_submissions': 181}
# {'total_submissions': 101}
# {'total_submissions': 154}
# {'total_submissions': 160}
# {'total_submissions': 134}
# {'total_submissions': 161}
# {'total_submissions': 104}
# {'total_submissions': 149}
# {'total_submissions': 160}
# {'total_submissions': 107}
# {'total_submissions': 157}
# {'total_submissions': 106}
# {'total_submissions': 140}
# {'total_submissions': 169}
# {'total_submissions': 149}
# {'total_submissions': 121}
# {'total_submissions': 110}
# {'total_submissions': 132}
# {'total_submissions': 122}
# {'total_submissions': 128}
# {'total_submissions': 127}
# {'total_submissions': 191}
# {'total_submissions': 170}
# {'total_submissions': 163}
# {'total_submissions': 181}
# {'total_submissions': 116}
# {'total_submissions': 128}
# {'total_submissions': 163}
# {'total_submissions': 114}
# {'total_submissions': 166}
# {'total_submissions': 150}
# {'total_submissions': 101}
# {'total_submissions': 136}
# {'total_submissions': 174}
# {'total_submissions': 125}
# {'total_submissions': 116}
# {'total_submissions': 174}
# {'total_submissions': 138}
# {'total_submissions': 125}
# {'total_submissions': 169}
# {'total_submissions': 164}
# {'total_submissions': 176}
# {'total_submissions': 197}
# {'total_submissions': 165}
# {'total_submissions': 158}
# {'total_submissions': 189}
# {'total_submissions': 136}
# {'total_submissions': 135}
# {'total_submissions': 193}
# {'total_submissions': 130}
# {'total_submissions': 177}
# {'total_submissions': 107}
# {'total_submissions': 174}
# {'total_submissions': 118}
# {'total_submissions': 111}
# {'total_submissions': 117}
# {'total_submissions': 155}
# {'total_submissions': 182}
# {'total_submissions': 107}
# {'total_submissions': 105}
# {'total_submissions': 157}
# {'total_submissions': 191}
# {'total_submissions': 107}
# {'total_submissions': 117}
# {'total_submissions': 123}
# {'total_submissions': 143}
# {'total_submissions': 109}
# {'total_submissions': 138}
# {'total_submissions': 148}
# {'total_submissions': 112}
# {'total_submissions': 132}
# {'total_submissions': 108}
# {'total_submissions': 104}
# {'total_submissions': 112}
# {'total_submissions': 147}
# {'total_submissions': 119}
# {'total_submissions': 124}
# {'total_submissions': 126}
# {'total_submissions': 157}
# {'total_submissions': 155}
# {'total_submissions': 117}
# {'total_submissions': 169}
# {'total_submissions': 191}
# {'total_submissions': 121}
# {'total_submissions': 130}
# {'total_submissions': 134}
# {'total_submissions': 188}
# {'total_submissions': 133}
# {'total_submissions': 101}
# {'total_submissions': 115}
# {'total_submissions': 176}
# {'total_submissions': 181}
# {'total_submissions': 148}
# {'total_submissions': 148}
# {'total_submissions': 105}
# {'total_submissions': 138}
# {'total_submissions': 108}
# {'total_submissions': 120}
# {'total_submissions': 110}
# {'total_submissions': 194}
# {'total_submissions': 198}
# {'total_submissions': 101}
# {'total_submissions': 187}
# {'total_submissions': 151}
# {'total_submissions': 190}
# {'total_submissions': 200}
# {'total_submissions': 127}
# {'total_submissions': 101}
# {'total_submissions': 100}
# {'total_submissions': 133}
# {'total_submissions': 147}
# {'total_submissions': 109}
# {'total_submissions': 194}
# {'total_submissions': 128}
# {'total_submissions': 139}
# {'total_submissions': 140}
# {'total_submissions': 150}
# {'total_submissions': 145}
# {'total_submissions': 179}
# {'total_submissions': 122}
# {'total_submissions': 116}
# {'total_submissions': 127}
# {'total_submissions': 146}
# {'total_submissions': 135}
# {'total_submissions': 196}
# {'total_submissions': 180}
# {'total_submissions': 131}
# {'total_submissions': 169}
# {'total_submissions': 119}
# {'total_submissions': 100}
# {'total_submissions': 186}
# {'total_submissions': 112}
# {'total_submissions': 147}
# {'total_submissions': 102}
# {'total_submissions': 151}
# {'total_submissions': 160}
# {'total_submissions': 169}
# {'total_submissions': 146}
# {'total_submissions': 116}
# {'total_submissions': 175}
# {'total_submissions': 191}
# {'total_submissions': 136}
# {'total_submissions': 190}
# {'total_submissions': 131}
# {'total_submissions': 190}
# {'total_submissions': 127}
# {'total_submissions': 143}
# {'total_submissions': 100}
# {'total_submissions': 189}
# {'total_submissions': 186}
# {'total_submissions': 177}
# {'total_submissions': 143}
# {'total_submissions': 109}
# {'total_submissions': 154}
# {'total_submissions': 105}
# {'total_submissions': 129}
# {'total_submissions': 196}
# {'total_submissions': 130}
# {'total_submissions': 119}
# {'total_submissions': 176}
# {'total_submissions': 121}
# {'total_submissions': 146}
# {'total_submissions': 114}
# {'total_submissions': 114}
# {'total_submissions': 112}
# {'total_submissions': 145}
# {'total_submissions': 166}
# {'total_submissions': 101}
# {'total_submissions': 197}
# {'total_submissions': 160}
# {'total_submissions': 104}
# {'total_submissions': 116}
# {'total_submissions': 144}
# {'total_submissions': 160}
# {'total_submissions': 124}
# {'total_submissions': 111}
# {'total_submissions': 161}
# {'total_submissions': 143}
# {'total_submissions': 190}
# {'total_submissions': 106}
# {'total_submissions': 114}
# {'total_submissions': 107}
# {'total_submissions': 115}
# {'total_submissions': 138}
# {'total_submissions': 133}
# {'total_submissions': 117}
# {'total_submissions': 145}
# {'total_submissions': 175}
# {'total_submissions': 135}
# {'total_submissions': 162}
# {'total_submissions': 126}
# {'total_submissions': 113}
# {'total_submissions': 190}
# {'total_submissions': 190}
# {'total_submissions': 178}
# {'total_submissions': 124}
# {'total_submissions': 108}
# {'total_submissions': 109}
# {'total_submissions': 176}
# {'total_submissions': 198}
# {'total_submissions': 195}
# {'total_submissions': 116}
# {'total_submissions': 148}
# {'total_submissions': 197}
# {'total_submissions': 164}
# {'total_submissions': 168}
# {'total_submissions': 189}
# {'total_submissions': 182}
# {'total_submissions': 131}
# {'total_submissions': 166}
# {'total_submissions': 106}
# {'total_submissions': 158}
# {'total_submissions': 139}
# {'total_submissions': 131}
# {'total_submissions': 100}
# {'total_submissions': 177}
# {'total_submissions': 135}
# {'total_submissions': 109}
# {'total_submissions': 118}
# {'total_submissions': 190}
# {'total_submissions': 166}
# {'total_submissions': 118}
# {'total_submissions': 101}
# {'total_submissions': 194}
# {'total_submissions': 128}
# {'total_submissions': 137}
# {'total_submissions': 193}
# {'total_submissions': 195}
# {'total_submissions': 100}
# {'total_submissions': 106}
# {'total_submissions': 113}
# {'total_submissions': 109}
# {'total_submissions': 185}
# {'total_submissions': 114}
# {'total_submissions': 167}
# {'total_submissions': 158}
# {'total_submissions': 102}
# {'total_submissions': 126}
# {'total_submissions': 108}
# {'total_submissions': 127}
# {'total_submissions': 137}
# {'total_submissions': 149}
# {'total_submissions': 117}
# {'total_submissions': 136}
# {'total_submissions': 156}
# {'total_submissions': 103}
# {'total_submissions': 150}
# {'total_submissions': 152}
# {'total_submissions': 158}
# {'total_submissions': 147}
# {'total_submissions': 127}
# {'total_submissions': 100}
# {'total_submissions': 153}
# {'total_submissions': 186}
# {'total_submissions': 150}
# {'total_submissions': 130}
# {'total_submissions': 124}
# {'total_submissions': 121}
# {'total_submissions': 153}
# {'total_submissions': 127}
# {'total_submissions': 122}
# {'total_submissions': 141}
# {'total_submissions': 186}
# {'total_submissions': 121}
# {'total_submissions': 135}
# {'total_submissions': 130}
# {'total_submissions': 193}
# {'total_submissions': 142}
# {'total_submissions': 200}
# {'total_submissions': 167}
# {'total_submissions': 145}
# {'total_submissions': 111}
# {'total_submissions': 134}
# {'total_submissions': 183}
# {'total_submissions': 111}
# {'total_submissions': 145}
# {'total_submissions': 186}
# {'total_submissions': 182}
# {'total_submissions': 192}
# {'total_submissions': 100}
# {'total_submissions': 110}
# {'total_submissions': 199}
# {'total_submissions': 154}
# {'total_submissions': 160}
# {'total_submissions': 149}
# {'total_submissions': 146}
# {'total_submissions': 148}
# {'total_submissions': 104}
# {'total_submissions': 130}
# {'total_submissions': 170}
# {'total_submissions': 134}
# {'total_submissions': 191}
# {'total_submissions': 184}
# {'total_submissions': 166}
# {'total_submissions': 169}
# {'total_submissions': 196}
# {'total_submissions': 135}
# {'total_submissions': 152}
# {'total_submissions': 126}
# {'total_submissions': 152}
# {'total_submissions': 166}
# {'total_submissions': 176}
# {'total_submissions': 142}
# {'total_submissions': 104}
# {'total_submissions': 195}
# {'total_submissions': 172}
# {'total_submissions': 144}
# {'total_submissions': 200}
# {'total_submissions': 138}
# {'total_submissions': 199}
# {'total_submissions': 147}
# {'total_submissions': 128}
# {'total_submissions': 124}
# {'total_submissions': 137}
# {'total_submissions': 107}
# {'total_submissions': 141}
# {'total_submissions': 127}
# {'total_submissions': 148}
# {'total_submissions': 188}
# {'total_submissions': 199}
# {'total_submissions': 166}
# {'total_submissions': 151}
# {'total_submissions': 158}
# {'total_submissions': 178}
# {'total_submissions': 105}
# {'total_submissions': 143}
# {'total_submissions': 109}
# {'total_submissions': 139}
# {'total_submissions': 116}
# {'total_submissions': 132}
# {'total_submissions': 109}
# {'total_submissions': 130}
# {'total_submissions': 170}
# {'total_submissions': 188}
# {'total_submissions': 104}
# {'total_submissions': 133}
# {'total_submissions': 121}
# {'total_submissions': 124}
# {'total_submissions': 159}
# {'total_submissions': 187}
# {'total_submissions': 118}
# {'total_submissions': 126}
# {'total_submissions': 145}
# {'total_submissions': 101}
# {'total_submissions': 104}
# {'total_submissions': 147}
# {'total_submissions': 102}
# {'total_submissions': 113}
# {'total_submissions': 135}
# {'total_submissions': 169}
# {'total_submissions': 114}
# {'total_submissions': 155}
# {'total_submissions': 148}
# {'total_submissions': 146}
# {'total_submissions': 147}
# {'total_submissions': 149}
# {'total_submissions': 158}
# {'total_submissions': 183}
# {'total_submissions': 161}
# {'total_submissions': 144}
# {'total_submissions': 136}
# {'total_submissions': 114}
# {'total_submissions': 165}
# {'total_submissions': 160}
# {'total_submissions': 188}
# {'total_submissions': 180}
# {'total_submissions': 148}
# {'total_submissions': 121}
# {'total_submissions': 107}
# {'total_submissions': 200}
# {'total_submissions': 136}
# {'total_submissions': 128}
# {'total_submissions': 154}
# {'total_submissions': 119}
# {'total_submissions': 160}
# {'total_submissions': 118}
# {'total_submissions': 120}
# {'total_submissions': 195}
# {'total_submissions': 158}
# {'total_submissions': 199}
# {'total_submissions': 131}
# {'total_submissions': 128}
# {'total_submissions': 158}
# {'total_submissions': 122}
# {'total_submissions': 182}
# {'total_submissions': 164}
# {'total_submissions': 121}
# {'total_submissions': 116}
# {'total_submissions': 185}
# {'total_submissions': 152}
# {'total_submissions': 156}
# {'total_submissions': 160}
# {'total_submissions': 106}
# {'total_submissions': 119}
# {'total_submissions': 162}
# {'total_submissions': 109}
# {'total_submissions': 176}
# {'total_submissions': 113}
# {'total_submissions': 111}
# {'total_submissions': 131}
# {'total_submissions': 122}
# {'total_submissions': 121}
# {'total_submissions': 138}
# {'total_submissions': 114}
# {'total_submissions': 144}
# {'total_submissions': 142}
# {'total_submissions': 133}
# {'total_submissions': 154}
# {'total_submissions': 125}
# {'total_submissions': 186}
# {'total_submissions': 156}
# {'total_submissions': 173}
# {'total_submissions': 186}
# {'total_submissions': 195}
# {'total_submissions': 197}
# {'total_submissions': 159}
# {'total_submissions': 115}
# {'total_submissions': 114}
# {'total_submissions': 123}
# {'total_submissions': 144}
# {'total_submissions': 178}
# {'total_submissions': 118}
# {'total_submissions': 190}
# {'total_submissions': 148}
# {'total_submissions': 194}
# {'total_submissions': 177}
# {'total_submissions': 164}
# {'total_submissions': 185}
# {'total_submissions': 133}
# {'total_submissions': 119}
# {'total_submissions': 132}
# {'total_submissions': 134}
# {'total_submissions': 136}
# {'total_submissions': 144}
# {'total_submissions': 195}
# {'total_submissions': 119}
# {'total_submissions': 147}
# {'total_submissions': 195}
# {'total_submissions': 107}
# {'total_submissions': 136}
# {'total_submissions': 168}
# {'total_submissions': 104}
# {'total_submissions': 193}
# {'total_submissions': 150}
# {'total_submissions': 187}
# {'total_submissions': 111}
# {'total_submissions': 145}
# {'total_submissions': 100}
# {'total_submissions': 173}
# {'total_submissions': 152}
# {'total_submissions': 160}
# {'total_submissions': 131}
# {'total_submissions': 118}
# {'total_submissions': 170}
# {'total_submissions': 200}
# {'total_submissions': 163}
# {'total_submissions': 183}
# {'total_submissions': 139}
# {'total_submissions': 113}
# {'total_submissions': 109}
# {'total_submissions': 110}
# {'total_submissions': 162}
# {'total_submissions': 102}
# {'total_submissions': 130}
# {'total_submissions': 134}
# {'total_submissions': 125}
# {'total_submissions': 103}
# {'total_submissions': 169}
# {'total_submissions': 109}
# {'total_submissions': 170}
# {'total_submissions': 137}
# {'total_submissions': 139}
# {'total_submissions': 157}
# {'total_submissions': 115}
# {'total_submissions': 101}
# {'total_submissions': 104}
# {'total_submissions': 149}
# {'total_submissions': 177}
# {'total_submissions': 128}
# {'total_submissions': 197}
# {'total_submissions': 184}
# {'total_submissions': 141}
# {'total_submissions': 181}
# {'total_submissions': 155}
# {'total_submissions': 131}
# {'total_submissions': 118}
# {'total_submissions': 104}
# {'total_submissions': 115}
# {'total_submissions': 132}
# {'total_submissions': 125}
# {'total_submissions': 103}
# {'total_submissions': 126}
# {'total_submissions': 120}
# {'total_submissions': 199}
# {'total_submissions': 114}
# {'total_submissions': 150}
# {'total_submissions': 132}
# {'total_submissions': 162}
# {'total_submissions': 160}
# {'total_submissions': 116}
# {'total_submissions': 133}
# {'total_submissions': 163}
# {'total_submissions': 141}
# {'total_submissions': 168}
# {'total_submissions': 151}
# {'total_submissions': 140}
# {'total_submissions': 189}
# {'total_submissions': 174}
# {'total_submissions': 164}
# {'total_submissions': 168}
# {'total_submissions': 119}
# {'total_submissions': 114}
# {'total_submissions': 168}
# {'total_submissions': 147}
# {'total_submissions': 172}
# {'total_submissions': 103}
# {'total_submissions': 151}
# {'total_submissions': 132}
# {'total_submissions': 106}
# {'total_submissions': 158}
# {'total_submissions': 157}
# {'total_submissions': 187}
# {'total_submissions': 191}
# {'total_submissions': 111}
# {'total_submissions': 116}
# {'total_submissions': 170}
# {'total_submissions': 104}
# {'total_submissions': 138}
# {'total_submissions': 101}
# {'total_submissions': 154}
# {'total_submissions': 196}
# {'total_submissions': 115}
# {'total_submissions': 108}
# {'total_submissions': 124}
# {'total_submissions': 137}
# {'total_submissions': 153}
# {'total_submissions': 142}
# {'total_submissions': 100}
# {'total_submissions': 200}
# {'total_submissions': 168}
# {'total_submissions': 106}
# {'total_submissions': 116}
# {'total_submissions': 136}
# {'total_submissions': 138}
# {'total_submissions': 128}
# {'total_submissions': 113}
# {'total_submissions': 185}
# {'total_submissions': 128}
# {'total_submissions': 150}
# {'total_submissions': 133}
# {'total_submissions': 183}
# {'total_submissions': 102}
# {'total_submissions': 104}
# {'total_submissions': 121}
# {'total_submissions': 155}
# {'total_submissions': 140}
# {'total_submissions': 172}
# {'total_submissions': 185}
# {'total_submissions': 117}
# {'total_submissions': 151}
# {'total_submissions': 166}
# {'total_submissions': 120}
# {'total_submissions': 174}
# {'total_submissions': 156}
# {'total_submissions': 184}
# {'total_submissions': 158}
# {'total_submissions': 172}
# {'total_submissions': 154}
# {'total_submissions': 151}
# {'total_submissions': 167}
# {'total_submissions': 115}
# {'total_submissions': 100}
# {'total_submissions': 194}
# {'total_submissions': 131}
# {'total_submissions': 185}
# {'total_submissions': 190}
# {'total_submissions': 105}
# {'total_submissions': 125}
# {'total_submissions': 128}
# {'total_submissions': 126}
# {'total_submissions': 167}
# {'total_submissions': 151}
# {'total_submissions': 152}
# {'total_submissions': 126}
# {'total_submissions': 188}
# {'total_submissions': 192}
# {'total_submissions': 129}
# {'total_submissions': 180}
# {'total_submissions': 134}
# {'total_submissions': 192}
# {'total_submissions': 180}
# {'total_submissions': 107}
# {'total_submissions': 135}
# {'total_submissions': 168}
# {'total_submissions': 159}
# {'total_submissions': 120}
# {'total_submissions': 151}
# {'total_submissions': 105}
# {'total_submissions': 138}
# {'total_submissions': 129}
# {'total_submissions': 143}
# {'total_submissions': 119}
# {'total_submissions': 165}
# {'total_submissions': 177}
# {'total_submissions': 164}
# {'total_submissions': 111}
# {'total_submissions': 116}
# {'total_submissions': 168}
# {'total_submissions': 171}
# {'total_submissions': 116}
# {'total_submissions': 194}
# {'total_submissions': 125}
# {'total_submissions': 141}
# {'total_submissions': 188}
# {'total_submissions': 119}
# {'total_submissions': 182}
# {'total_submissions': 162}
# {'total_submissions': 100}
# {'total_submissions': 114}
# {'total_submissions': 144}
# {'total_submissions': 126}
# {'total_submissions': 120}
# {'total_submissions': 109}
# {'total_submissions': 134}
# {'total_submissions': 142}
# {'total_submissions': 149}
# {'total_submissions': 162}
# {'total_submissions': 174}
# {'total_submissions': 135}
# {'total_submissions': 119}
# {'total_submissions': 149}
# {'total_submissions': 106}
# {'total_submissions': 100}
# {'total_submissions': 103}
# {'total_submissions': 105}
# {'total_submissions': 177}
# {'total_submissions': 125}
# {'total_submissions': 107}
# {'total_submissions': 127}
# {'total_submissions': 195}
# {'total_submissions': 103}
# {'total_submissions': 182}
# {'total_submissions': 127}
# {'total_submissions': 137}
# {'total_submissions': 166}
# {'total_submissions': 152}
# {'total_submissions': 188}
# {'total_submissions': 181}
# {'total_submissions': 179}
# {'total_submissions': 116}

# %% [markdown]
# **Count how  many - where the total_submissions is between 100 and 200, both inclusive?**

# %%
find = {'total_submissions':{'$gte':100,'$lte':200}} 
db.challenge.count_documents(find)
# Out:
# 1300

# %% [markdown]
# **Count how  many - where either the challenge has been attempted by exactly 100 users or where the total_submissions is between 100 and 200, both inclusive?**

# %%
find =     {
        '$or':[
                {'users':{'$size' : 100}},
                {'total_submissions':{'$gte':100,'$lte':200}}
            
        ]
    }
db.challenge.count_documents(find)
# Out:
# 1303

# %%
# cur = db.challenge.find(
#     # query expression
#     {
#         '$or':[
#                 {'users':{'$size' : 100}},
#                 {'total_submissions':{'$gte':100,'$lte':200}}
            
#         ]
#     },
    
#     # projection
#     {
#         'users':1,
#         'total_submissions':1,
#         '_id':0
#     })
# # Print docs
# for doc in cur :
#     pp.pprint(doc)

# %% [markdown]
# **Get top 5 docs**

# %%
cur = db.challenge.find(
    # query expression
    {
        '$or':[
                {'users':{'$size' : 100}},
                {'total_submissions':{'$gte':100,'$lte':200}}
            
        ]
    },
    
    # projection
    {
        'challenge_id':1,
        'users':1,
        'total_submissions':1,
        '_id':0
    }).limit(5)
# Print docs
for doc in cur :
    pp.pprint(doc)
# Out:
# {'challenge_id': 'CI23482',
#  'total_submissions': 137,
#  'users': [26451, 51751, 63658, 67869, 84316, 85874, 90009, 94425]}
# {'challenge_id': 'CI23494',
#  'total_submissions': 173,
#  'users': [77084, 107362, 109350]}
# {'challenge_id': 'CI23497',
#  'total_submissions': 195,
#  'users': [19464,
#            19685,
#            21670,
#            27836,
#            30097,
#            30328,
#            30329,
#            30764,
#            30851,
#            31120,
#            32248,
#            33032,
#            35553,
#            35641,
#            35673,
#            35836,
#            36683,
#            36765,
#            37221,
#            39013,
#            39951,
#            40092,
#            40117,
#            40479,
#            42551,
#            42569,
#            43001,
#            43085,
#            43086,
#            43091,
#            43232,
#            45608,
#            45633,
#            45672,
#            45675,
#            46837,
#            46854,
#            47077,
#            47079,
#            47195,
#            47198,
#            47202,
#            47464,
#            48325,
#            48327,
#            49310,
#            50361,
#            50888,
#            53829,
#            54406,
#            54424,
#            55476,
#            56464,
#            56578,
#            56580,
#            56667,
#            56678,
#            56777,
#            56796,
#            58055,
#            59030,
#            59150,
#            59151,
#            59164,
#            59691,
#            59756,
#            60109,
#            60152,
#            60203,
#            60352,
#            60725,
#            61641,
#            61661,
#            61670,
#            62135,
#            62136,
#            62957,
#            63225,
#            63226,
#            63786,
#            65306,
#            66119,
#            66562,
#            66759,
#            67541,
#            67549,
#            67551,
#            67610,
#            67966,
#            67971,
#            68025,
#            68172,
#            68203,
#            68232,
#            68252,
#            68282,
#            68289,
#            68295,
#            68303,
#            68335,
#            68348,
#            68373,
#            68400,
#            68471,
#            68508,
#            68532,
#            68547,
#            68548,
#            68610,
#            68661,
#            68954,
#            69012,
#            70141,
#            70143,
#            72656,
#            72664,
#            73365,
#            73378,
#            73382,
#            73393,
#            73617,
#            73756,
#            75148,
#            75877,
#            77693,
#            77730,
#            77754,
#            77760,
#            77761,
#            78731,
#            78922,
#            78939,
#            78954,
#            79394,
#            80066,
#            80214,
#            80226,
#            80863,
#            81358,
#            81827,
#            81855,
#            81862,
#            81863,
#            82595,
#            82602,
#            82612,
#            82655,
#            83489,
#            83532,
#            84267,
#            84725,
#            84829,
#            84830,
#            84843,
#            84848,
#            84851,
#            84859,
#            85345,
#            85346,
#            85347,
#            85365,
#            85366,
#            85369,
#            85370,
#            85371,
#            85409,
#            85413,
#            85415,
#            85421,
#            85479,
#            85806,
#            85890,
#            85899,
#            85930,
#            85940,
#            85952,
#            85961,
#            85963,
#            85964,
#            86497,
#            86499,
#            86504,
#            86540,
#            86965,
#            86966,
#            86974,
#            86984,
#            87636,
#            88058,
#            88116,
#            88164,
#            88600,
#            88685,
#            89965,
#            90062,
#            90095,
#            90102,
#            90103,
#            90116,
#            90223,
#            90230,
#            90232,
#            90927,
#            90930,
#            90931,
#            90932,
#            90935,
#            90950,
#            90966,
#            90976,
#            90993,
#            91005,
#            91014,
#            91083,
#            91085,
#            91248,
#            91270,
#            91277,
#            91688,
#            94776,
#            95208,
#            95641,
#            97318,
#            98344,
#            98435,
#            99319,
#            99708,
#            100801,
#            102716,
#            103170,
#            103474,
#            103476,
#            103477,
#            103479,
#            103491,
#            103492,
#            103493,
#            103494,
#            103511,
#            103517,
#            104078,
#            104349,
#            104928,
#            104929,
#            105029,
#            106009,
#            106011,
#            106013,
#            106014,
#            106015,
#            106459,
#            106460,
#            106461,
#            106463,
#            106465,
#            106466,
#            106483,
#            108596,
#            108726,
#            109111,
#            109206,
#            109218,
#            109219,
#            109485,
#            109770,
#            109777,
#            109778,
#            109790,
#            109792,
#            109794,
#            109806,
#            109807,
#            110162,
#            110208,
#            111610,
#            111614,
#            111631,
#            111639,
#            111640,
#            111642,
#            111647,
#            111651,
#            113345,
#            113377,
#            113378,
#            113387,
#            113394,
#            113398,
#            113408,
#            113415,
#            113460,
#            113511,
#            113536]}
# {'challenge_id': 'CI23500', 'total_submissions': 112, 'users': [72774]}
# {'challenge_id': 'CI23516',
#  'total_submissions': 104,
#  'users': [5610,
#            7475,
#            9183,
#            10949,
#            11159,
#            12209,
#            12520,
#            13656,
#            14395,
#            15325,
#            17938,
#            18283,
#            18330,
#            18807,
#            18814,
#            20922,
#            21451,
#            21953,
#            22516,
#            23535,
#            23542,
#            24851,
#            25005,
#            25009,
#            25334,
#            26210,
#            26451,
#            26774,
#            27873,
#            29498,
#            29834,
#            30660,
#            30820,
#            31298,
#            31422,
#            31429,
#            31608,
#            32234,
#            32373,
#            32728,
#            33431,
#            33883,
#            36069,
#            36142,
#            37025,
#            37155,
#            37544,
#            37578,
#            37585,
#            39265,
#            40417,
#            40825,
#            40827,
#            41104,
#            41300,
#            41515,
#            41851,
#            41898,
#            42588,
#            45801,
#            46314,
#            46380,
#            46665,
#            46695,
#            48075,
#            48250,
#            48564,
#            48601,
#            49022,
#            49553,
#            49555,
#            51749,
#            51909,
#            52363,
#            52660,
#            53267,
#            56150,
#            56264,
#            57055,
#            57511,
#            57994,
#            58075,
#            58377,
#            59303,
#            59875,
#            61124,
#            63721,
#            63726,
#            64490,
#            64542,
#            64574,
#            64680,
#            65010,
#            66358,
#            66642,
#            67353,
#            67726,
#            67855,
#            67869,
#            68917,
#            70059,
#            70505,
#            72774,
#            73239,
#            73582,
#            73615,
#            73717,
#            75816,
#            76712,
#            77208,
#            78389,
#            78997,
#            79032,
#            79422,
#            79424,
#            79714,
#            79716,
#            80937,
#            81549,
#            82091,
#            82185,
#            83640,
#            84046,
#            84316,
#            84388,
#            84976,
#            85597,
#            85654,
#            88599,
#            88630,
#            88820,
#            88822,
#            89299,
#            89411,
#            90009,
#            90261,
#            90466,
#            92547,
#            92569,
#            93802,
#            93867,
#            93869,
#            93871,
#            93872,
#            93890,
#            94425,
#            94441,
#            96243,
#            96411,
#            97147,
#            97276,
#            99832,
#            100657,
#            101567,
#            102089,
#            102216,
#            102235,
#            102262,
#            102419,
#            102588,
#            103073,
#            103074,
#            103799,
#            104082,
#            104453,
#            104718,
#            105602,
#            105625,
#            105627,
#            105773,
#            105774,
#            106490,
#            106492,
#            106508,
#            106665,
#            107111,
#            108136,
#            108703,
#            109522,
#            110269,
#            111605,
#            112783,
#            113025]}

# %% [markdown]
# ### Q7.
#
# How documents are there where either the `publish_date > 2010-01-01` and `total_submissions > 100`, or the `publish_date < 2000-01-01` and `total_submissions > 1000` ?

# %%
pp.pprint(
    db.challenge.find_one()
)
# Out:
# {'_id': ObjectId('60dab9f75945974466d8d64d'),
#  'challenge_id': 'CI23478',
#  'programming_language': 2,
#  'total_submissions': 37,
#  'publish_date': datetime.datetime(2006, 6, 5, 0, 0),
#  'author': {'id': 'AI563576', 'gender': 'M', 'org_id': 'AOI100001'},
#  'users': [32876, 88820, 97150, 97359]}

# %%
cur = db.challenge.find(
    # query expression
    {
        '$or':[
            # `publish_date > 2010-01-01` and `total_submissions > 100`
            {
                '$and':[
                        {'publish_date':{'$gt':datetime(2010,1,1)}},
                        {'total_submissions':{'$gt':100}}
                     ]
                
            },
            # `publish_date < 2000-01-01` and `total_submissions > 1000
            {
                '$and':[
                        {'publish_date':{'$lt':datetime(2000,1,1)}},
                        {'total_submissions':{'$gt':1000}}
                     ]
                
            }
        ]
   },

    # projection
    {
        'publish_date':1,
        'total_submissions':1,
        '_id':0
    })
# Print docs
for doc in cur :
    pp.pprint(doc)
# Out:
# {'total_submissions': 1904, 'publish_date': datetime.datetime(1999, 8, 9, 0, 0)}
# {'total_submissions': 2735,
#  'publish_date': datetime.datetime(1999, 9, 15, 0, 0)}
# {'total_submissions': 1818,
#  'publish_date': datetime.datetime(1999, 9, 24, 0, 0)}
# {'total_submissions': 1096,
#  'publish_date': datetime.datetime(1999, 6, 10, 0, 0)}
# {'total_submissions': 1258,
#  'publish_date': datetime.datetime(1999, 10, 18, 0, 0)}
# {'total_submissions': 2033,
#  'publish_date': datetime.datetime(1999, 10, 29, 0, 0)}
# {'total_submissions': 1642,
#  'publish_date': datetime.datetime(1999, 8, 11, 0, 0)}
# {'total_submissions': 2194,
#  'publish_date': datetime.datetime(1999, 11, 17, 0, 0)}
# {'total_submissions': 1223,
#  'publish_date': datetime.datetime(1999, 1, 12, 0, 0)}
# {'total_submissions': 102, 'publish_date': datetime.datetime(2010, 4, 2, 0, 0)}
# {'total_submissions': 162, 'publish_date': datetime.datetime(2010, 5, 2, 0, 0)}
# {'total_submissions': 146, 'publish_date': datetime.datetime(2010, 4, 2, 0, 0)}
# {'total_submissions': 106, 'publish_date': datetime.datetime(2010, 5, 2, 0, 0)}
# {'total_submissions': 123, 'publish_date': datetime.datetime(2010, 5, 2, 0, 0)}
# {'total_submissions': 202, 'publish_date': datetime.datetime(2010, 5, 2, 0, 0)}
# {'total_submissions': 238, 'publish_date': datetime.datetime(2010, 3, 18, 0, 0)}
# {'total_submissions': 635, 'publish_date': datetime.datetime(2010, 7, 4, 0, 0)}
# {'total_submissions': 121, 'publish_date': datetime.datetime(2010, 4, 24, 0, 0)}
# {'total_submissions': 195, 'publish_date': datetime.datetime(2010, 5, 14, 0, 0)}
# {'total_submissions': 201, 'publish_date': datetime.datetime(2010, 5, 24, 0, 0)}
# {'total_submissions': 184, 'publish_date': datetime.datetime(2010, 12, 6, 0, 0)}
# {'total_submissions': 3962,
#  'publish_date': datetime.datetime(1999, 9, 13, 0, 0)}
# {'total_submissions': 1620,
#  'publish_date': datetime.datetime(1999, 9, 22, 0, 0)}
# {'total_submissions': 5516,
#  'publish_date': datetime.datetime(1999, 4, 10, 0, 0)}
# {'total_submissions': 2413,
#  'publish_date': datetime.datetime(1999, 10, 15, 0, 0)}
# {'total_submissions': 3956,
#  'publish_date': datetime.datetime(1999, 10, 27, 0, 0)}
# {'total_submissions': 1197,
#  'publish_date': datetime.datetime(1999, 5, 11, 0, 0)}
# {'total_submissions': 3901,
#  'publish_date': datetime.datetime(1999, 11, 15, 0, 0)}
# {'total_submissions': 1206,
#  'publish_date': datetime.datetime(1999, 11, 29, 0, 0)}
# {'total_submissions': 1119,
#  'publish_date': datetime.datetime(1999, 8, 12, 0, 0)}
# {'total_submissions': 4566,
#  'publish_date': datetime.datetime(1999, 10, 9, 0, 0)}
# {'total_submissions': 2550,
#  'publish_date': datetime.datetime(1999, 9, 20, 0, 0)}
# {'total_submissions': 3773,
#  'publish_date': datetime.datetime(1999, 1, 10, 0, 0)}
# {'total_submissions': 1552,
#  'publish_date': datetime.datetime(1999, 3, 11, 0, 0)}
# {'total_submissions': 1641,
#  'publish_date': datetime.datetime(1999, 12, 11, 0, 0)}
# {'total_submissions': 1211,
#  'publish_date': datetime.datetime(1999, 11, 24, 0, 0)}
# {'total_submissions': 2482,
#  'publish_date': datetime.datetime(1999, 6, 12, 0, 0)}
# {'total_submissions': 2131, 'publish_date': datetime.datetime(1999, 8, 9, 0, 0)}
# {'total_submissions': 6968, 'publish_date': datetime.datetime(1999, 8, 9, 0, 0)}
# {'total_submissions': 1962,
#  'publish_date': datetime.datetime(1999, 9, 17, 0, 0)}
# {'total_submissions': 1313,
#  'publish_date': datetime.datetime(1999, 10, 20, 0, 0)}
# {'total_submissions': 2193,
#  'publish_date': datetime.datetime(1999, 3, 12, 0, 0)}
# {'total_submissions': 1437, 'publish_date': datetime.datetime(1999, 8, 9, 0, 0)}
# {'total_submissions': 1521,
#  'publish_date': datetime.datetime(1999, 10, 9, 0, 0)}
# {'total_submissions': 6376,
#  'publish_date': datetime.datetime(1999, 8, 26, 0, 0)}

# %%
db.challenge.count_documents(
    # query expression
    {
        '$or':[
            # `publish_date > 2010-01-01` and `total_submissions > 100`
            {
                '$and':[
                        {'publish_date':{'$gt':datetime(2010,1,1)}},
                        {'total_submissions':{'$gt':100}}
                     ]
                
            },
            # `publish_date < 2000-01-01` and `total_submissions > 1000
            {
                '$and':[
                        {'publish_date':{'$lt':datetime(2000,1,1)}},
                        {'total_submissions':{'$gt':1000}}
                     ]
                
            }
        ]
   }
)
# Out:
# 45
